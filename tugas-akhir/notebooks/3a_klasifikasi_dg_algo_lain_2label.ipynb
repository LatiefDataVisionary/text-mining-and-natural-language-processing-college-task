# %% [markdown]
# ## **Import library**

# %%
# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split, cross_val_score, GridSearchCV
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz


from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_graphviz
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay,
    roc_auc_score,
    roc_curve
)

import matplotlib.pyplot as plt
import seaborn as sns # Untuk visualisasi yang lebih menarik
import graphviz # Untuk visualisasi graphviz
import nltk # Untuk pra-pemrosesan teks lebih lanjut
from nltk.stem import WordNetLemmatizer # Untuk lemmatization
from nltk.corpus import stopwords as nltk_stopwords # Untuk custom stop words

# Feature selection
from sklearn.feature_selection import SelectKBest, chi2

# Download resource NLTK yang mungkin dibutuhkan
# Catch the LookupError directly when nltk.data.find fails
try:
    nltk.data.find('corpora/wordnet')
except LookupError:
    print("NLTK resource 'wordnet' not found. Downloading...")
    nltk.download('wordnet')
except Exception as e:
    print(f"An unexpected error occurred while checking/downloading 'wordnet': {e}")

try:
    nltk.data.find('corpora/omw-1.4')
except LookupError:
    print("NLTK resource 'omw-1.4' not found. Downloading...")
    nltk.download('omw-1.4') # WordNet multilingual resource
except Exception as e:
    print(f"An unexpected error occurred while checking/downloading 'omw-1.4': {e}")

try:
    nltk.data.find('corpora/stopwords')
except LookupError:
    print("NLTK resource 'stopwords' not found. Downloading...")
    nltk.download('stopwords')
except Exception as e:
    print(f"An unexpected error occurred while checking/downloading 'stopwords': {e}")

# Smote
from imblearn.over_sampling import SMOTE

# PYtorch
import torch
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Random
import random

#Import svm model
from sklearn import svm

# Logistic regression
# import the class
from sklearn.linear_model import LogisticRegression

# Pengaturan umum untuk plot agar lebih menarik
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_palette("viridis") # Atau palet lain seperti 'pastel', 'muted'
# Out:
# NLTK resource 'wordnet' not found. Downloading...
# NLTK resource 'omw-1.4' not found. Downloading...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ## **Load dataset**

# %%
path = 'https://raw.githubusercontent.com/LatiefDataVisionary/text-mining-and-natural-language-processing-college-task/refs/heads/main/datasets/ramadan_labeled_sentiment.csv'
# path = 'https://raw.githubusercontent.com/LatiefDataVisionary/text-mining-and-natural-language-processing-college-task/refs/heads/main/datasets/ramadan_labeled_sentiment_3label.csv'
df = pd.read_csv(path)

print(f"Dataset berhasil di-load dari: {path}")
print(f"Jumlah baris: {df.shape[0]}, Jumlah kolom: {df.shape[1]}")
# Out:
# Dataset berhasil di-load dari: https://raw.githubusercontent.com/LatiefDataVisionary/text-mining-and-natural-language-processing-college-task/refs/heads/main/datasets/ramadan_labeled_sentiment.csv
# Jumlah baris: 836, Jumlah kolom: 8

# %%
df
# Out:
#                                            tweet_clean  \
# 0    ['abraj', 'al', 'bait', 'clock', 'tower', 'bea...
# 1    ['accounts', 'recognised', 'ramadan', 'none', ...
# 2    ['admin', 'post', 'peaceful', 'ramadan', 'cele...
# 3               ['admin', 'post', 'ramadan', 'norway']
# 4    ['admin', 'post', 'ramadan', 'usual', 'peacefu...
# ..                                                 ...
# 831  ['ya', 'allah', 'please', 'remove', 'procrasti...
# 832  ['yaqeen', 'launched', 'official', 'urdu', 'yo...
# 833  ['yasser', 'abu', 'daqqa', 'recently', 'freed'...
# 834  ['young', 'arabs', 'took', 'streets', 'last', ...
# 835  ['zarafshan', 'shiraz', 'hindustan', 'times', ...
#
#                                                  Tweet sentiment  \
# 0    abraj al bait clock tower beams indicating com...  negative
# 1    accounts recognised ramadan none recognised be...  negative
# 2    admin post peaceful ramadan celebrations east ...  positive
# 3                            admin post ramadan norway  negative
# 4    admin post ramadan usual peaceful start englan...  positive
# ..                                                 ...       ...
# 831  ya allah please remove procrastination body ra...  positive
# 832  yaqeen launched official urdu youtube channel ...  positive
# 833  yasser abu daqqa recently freed palestinian de...  negative
# 834  young arabs took streets last night shouting a...  negative
# 835  zarafshan shiraz hindustan times confirms horm...  positive
#
#                                       sentiment_scores    neg    neu    pos  \
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 1    {'neg': 0.147, 'neu': 0.853, 'pos': 0.0, 'comp...  0.147  0.853  0.000
# 2    {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...  0.000  0.714  0.286
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 4    {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...  0.000  0.775  0.225
# ..                                                 ...    ...    ...    ...
# 831  {'neg': 0.171, 'neu': 0.348, 'pos': 0.481, 'co...  0.171  0.348  0.481
# 832  {'neg': 0.0, 'neu': 0.688, 'pos': 0.312, 'comp...  0.000  0.688  0.312
# 833  {'neg': 0.336, 'neu': 0.494, 'pos': 0.17, 'com...  0.336  0.494  0.170
# 834  {'neg': 0.19, 'neu': 0.747, 'pos': 0.063, 'com...  0.190  0.747  0.063
# 835  {'neg': 0.0, 'neu': 0.817, 'pos': 0.183, 'comp...  0.000  0.817  0.183
#
#      compound
# 0      0.0000
# 1     -0.4767
# 2      0.4939
# 3      0.0000
# 4      0.4939
# ..        ...
# 831    0.8689
# 832    0.7003
# 833   -0.7506
# 834   -0.6597
# 835    0.5719
#
# [836 rows x 8 columns]

# %% [markdown]
# ## **Preprocessing**

# %%
print("Label sentimen sebelum konversi:")
print(df['sentiment'].unique()) # Menampilkan nilai unik sebelum mapping

df['sentiment_label'] = df['sentiment'].copy() # Simpan label asli untuk referensi
df['sentiment'] = df['sentiment'].map({'neutral':2, 'positive': 1, 'negative' : 0})
# df['sentiment'] = df['sentiment'].map({'positive': 1, 'negative' : 0})

print("\nLabel sentimen setelah konversi ke numerik (0 dan 1):")
print(df['sentiment'].unique()) # Menampilkan nilai unik setelah mapping
display(df[['Tweet', 'sentiment_label', 'sentiment']].head())
# Out:
# Label sentimen sebelum konversi:
# ['negative' 'positive']
#
# Label sentimen setelah konversi ke numerik (0 dan 1):
# [0 1]
#                                                Tweet sentiment_label  \
# 0  abraj al bait clock tower beams indicating com...        negative
# 1  accounts recognised ramadan none recognised be...        negative
# 2  admin post peaceful ramadan celebrations east ...        positive
# 3                          admin post ramadan norway        negative
# 4  admin post ramadan usual peaceful start englan...        positive
#
#    sentiment
# 0          0
# 1          0
# 2          1
# 3          0
# 4          1

# %%
# Fungsi untuk menggabungkan list kata menjadi string
def join_text_list(text_list_str):
    if isinstance(text_list_str, str):
        try:
            actual_list = eval(text_list_str)
            if isinstance(actual_list, list):
                return ' '.join(actual_list)
            else:
                # Jika eval menghasilkan bukan list (misalnya, sudah string utuh)
                return str(text_list_str) # Kembalikan sebagai string
        except Exception: # Tangkap error lebih umum dari eval
            return str(text_list_str) # Kembalikan string aslinya jika eval gagal
    elif isinstance(text_list_str, list):
        return ' '.join(text_list_str)
    return str(text_list_str) # Pastikan output selalu string

df['text_processed_raw'] = df['tweet_clean'].apply(join_text_list)

# Inisialisasi Lemmatizer dan Stop Words
lemmatizer = WordNetLemmatizer()
english_stopwords = set(nltk_stopwords.words('english'))
# Anda bisa tambahkan custom stop words di sini jika perlu
# custom_stopwords = {'ramadan', 'mubarak', ...}
# all_stopwords = english_stopwords.union(custom_stopwords)

def preprocess_text_advanced(text):
    if not isinstance(text, str): # Pastikan input adalah string
        return ""
    words = text.split() # Tokenisasi sederhana
    # Lemmatisasi dan penghapusan stop words
    processed_words = [lemmatizer.lemmatize(word.lower()) for word in words if word.lower() not in english_stopwords and word.isalpha()] # Hanya ambil kata alpha
    return ' '.join(processed_words)

print("\nMenerapkan pra-pemrosesan teks lanjutan (lemmatization, stop word removal)...")
df['text_processed'] = df['text_processed_raw'].apply(preprocess_text_advanced)

print("\nContoh hasil 'text_processed' setelah pra-pemrosesan lanjutan:")
display(df[['tweet_clean', 'text_processed_raw', 'text_processed']].head())
# Out:
# Menerapkan pra-pemrosesan teks lanjutan (lemmatization, stop word removal)...
#
# Contoh hasil 'text_processed' setelah pra-pemrosesan lanjutan:
#                                          tweet_clean  \
# 0  ['abraj', 'al', 'bait', 'clock', 'tower', 'bea...
# 1  ['accounts', 'recognised', 'ramadan', 'none', ...
# 2  ['admin', 'post', 'peaceful', 'ramadan', 'cele...
# 3             ['admin', 'post', 'ramadan', 'norway']
# 4  ['admin', 'post', 'ramadan', 'usual', 'peacefu...
#
#                                   text_processed_raw  \
# 0  abraj al bait clock tower beams indicating com...
# 1  accounts recognised ramadan none recognised be...
# 2  admin post peaceful ramadan celebrations east ...
# 3                          admin post ramadan norway
# 4  admin post ramadan usual peaceful start englan...
#
#                                       text_processed
# 0  abraj al bait clock tower beam indicating comm...
# 1  account recognised ramadan none recognised beg...
# 2  admin post peaceful ramadan celebration east l...
# 3                          admin post ramadan norway
# 4  admin post ramadan usual peaceful start englan...

# %%
# # --- MULAI KODE UNTUK LANGKAH 1: PREPROCESSING TEKS ---
# # Pastikan NLTK resources sudah ada atau diunduh
# # (Kode ini sebaiknya ada di awal notebook, saya sertakan di sini untuk kelengkapan)
# import nltk

# # Explicitly download required NLTK resources
# nltk.download('wordnet', quiet=True)
# nltk.download('omw-1.4', quiet=True)
# nltk.download('stopwords', quiet=True)
# nltk.download('punkt', quiet=True)
# nltk.download('punkt_tab', quiet=True)


# # Import library yang relevan untuk tahap ini
# import re
# from nltk.tokenize import word_tokenize
# from nltk.stem import PorterStemmer # Menggunakan PorterStemmer untuk stemming
# from nltk.corpus import stopwords as nltk_stopwords
# from nltk.stem import WordNetLemmatizer # Import WordNetLemmatizer

# # pandas dan WordNetLemmatizer sudah diimport sebelumnya

# # Fungsi untuk menggabungkan list kata menjadi string (masih relevan dari kode awal Anda)
# def join_text_list(text_list_str):
#     if isinstance(text_list_str, str):
#         try:
#             actual_list = eval(text_list_str)
#             if isinstance(actual_list, list):
#                 return ' '.join(actual_list)
#             else:
#                 return str(text_list_str)
#         except Exception:
#             return str(text_list_str)
#     elif isinstance(text_list_str, list):
#         return ' '.join(text_list_str)
#     return str(text_list_str)

# # Mengaplikasikan join_text_list ke kolom 'tweet_clean' untuk mendapatkan teks mentah
# # yang akan diproses. Kolom ini digunakan agar proses evaluasi lebih konsisten
# # dengan bagaimana 'text_processed_raw' dibuat di kode asli.
# df['text_processed_raw'] = df['tweet_clean'].apply(join_text_list)


# # Inisialisasi Lemmatizer dan Stop Words
# # Menggunakan WordNetLemmatizer untuk lemmatization
# lemmatizer = WordNetLemmatizer()
# english_stopwords = set(nltk_stopwords.words('english'))
# # Anda bisa tambahkan custom stop words di sini jika perlu, contoh:
# # custom_stopwords = {'ramadan', 'mubarak', 'also', 'like', 'would'}
# # all_stopwords = english_stopwords.union(custom_stopwords)
# # Untuk saat ini, kita gunakan default NLTK English stopwords

# def preprocess_text_step1(text):
#     if not isinstance(text, str): # Pastikan input adalah string
#         return ""

#     # 1. Case Folding: Mengubah semua teks menjadi huruf kecil
#     text = text.lower()

#     # Tambahan: Menghilangkan URL, mention, hashtag (opsional, tapi baik untuk tweet)
#     text = re.sub(r"http\S+|www\S+|https\S+", '', text, flags=re.MULTILINE) # Menghilangkan URL
#     text = re.sub(r'\@\w+|\#','', text) # Menghilangkan mention dan hashtag symbols

#     # Tambahan: Menghilangkan karakter non-alfanumerik kecuali spasi (menyisakan kata dan angka)
#     # Jika ingin hanya alphabet: text = re.sub(r'[^a-zA-Z\s]', '', text)
#     text = re.sub(r'[^a-zA-Z0-9\s]', '', text) # Membiarkan angka, atau bisa juga dihilangkan jika diinginkan


#     # 2. Tokenizing: Memecah teks menjadi token/kata
#     # Menggunakan word_tokenize dari NLTK untuk tokenisasi yang lebih baik
#     tokens = word_tokenize(text, language='english') # Explicitly specify language

#     # 3. Stopword Removal dan 4. Lemmatization
#     processed_tokens = []
#     for token in tokens:
#         # Hanya proses token yang berupa alphabet dan bukan stopword
#         if token.isalpha() and token not in english_stopwords:
#             # Lakukan lemmatization
#             # 'v' untuk verb, 'n' untuk noun, dll. Defaultnya 'n'. Mungkin perlu eksplorasi POS tagging
#             lemmatized_token = lemmatizer.lemmatize(token)
#             processed_tokens.append(lemmatized_token)

#     return ' '.join(processed_tokens)

# print("\nMemulai Tahap 1: Pra-pemrosesan Teks (Case Folding, Tokenizing, Stopword Removal, Lemmatization)...")
# # Kolom 'text_processed' akan berisi hasil dari pra-pemrosesan lengkap tahap 1 ini
# df['text_processed'] = df['text_processed_raw'].apply(preprocess_text_step1)

# print("\nContoh hasil 'text_processed' setelah pra-pemrosesan Tahap 1:")
# display(df[['tweet_clean', 'text_processed_raw', 'text_processed', 'sentiment']].head())

# print("\nMemeriksa missing values di kolom 'text_processed' setelah pra-pemrosesan:")
# print(f"Jumlah missing values: {df['text_processed'].isnull().sum()}")
# # Jika ada missing values (misal dari tweet yang jadi string kosong setelah preprocessing),
# # kita bisa isi dengan string kosong agar TfidfVectorizer tidak error
# df['text_processed'].fillna('', inplace=True)
# print(f"Jumlah missing values setelah fillna: {df['text_processed'].isnull().sum()}")

# # --- AKHIR KODE UNTUK LANGKAH 1 ---
# Out:
# Memulai Tahap 1: Pra-pemrosesan Teks (Case Folding, Tokenizing, Stopword Removal, Lemmatization)...
#
# Contoh hasil 'text_processed' setelah pra-pemrosesan Tahap 1:
#                                          tweet_clean  \
# 0  ['abraj', 'al', 'bait', 'clock', 'tower', 'bea...
# 1  ['accounts', 'recognised', 'ramadan', 'none', ...
# 2  ['admin', 'post', 'peaceful', 'ramadan', 'cele...
# 3             ['admin', 'post', 'ramadan', 'norway']
# 4  ['admin', 'post', 'ramadan', 'usual', 'peacefu...
#
#                                   text_processed_raw  \
# 0  abraj al bait clock tower beams indicating com...
# 1  accounts recognised ramadan none recognised be...
# 2  admin post peaceful ramadan celebrations east ...
# 3                          admin post ramadan norway
# 4  admin post ramadan usual peaceful start englan...
#
#                                       text_processed  sentiment
# 0  abraj al bait clock tower beam indicating comm...          0
# 1  account recognised ramadan none recognised beg...          0
# 2  admin post peaceful ramadan celebration east l...          1
# 3                          admin post ramadan norway          0
# 4  admin post ramadan usual peaceful start englan...          1
# Memeriksa missing values di kolom 'text_processed' setelah pra-pemrosesan:
# Jumlah missing values: 0
# Jumlah missing values setelah fillna: 0
# <ipython-input-228-3990019563>:96: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['text_processed'].fillna('', inplace=True)

# %%
# Kita bisa coba tuning parameter TF-IDF ini nantinya jika akurasi masih kurang
tfidf = TfidfVectorizer(
    max_features=1500,    # Coba tingkatkan jumlah fitur
    ngram_range=(1, 2),   # Tetap pertimbangkan unigram dan bigram
    stop_words='english', # Stop words sudah ditangani sebagian di pra-pemrosesan, tapi bisa tetap di sini
    min_df=3,             # Abaikan term yang muncul di kurang dari 3 dokumen
    max_df=0.9            # Abaikan term yang muncul di lebih dari 90% dokumen (terlalu umum)
)

X = tfidf.fit_transform(df['text_processed'])
y = df['sentiment'].astype(int) # Pastikan y adalah integer



# smote=SMOTE(sampling_strategy='auto')
# X,y=smote.fit_resample(X,y)
# from imblearn.under_sampling import RandomUnderSampler

# undersampler = RandomUnderSampler(sampling_strategy='majority', random_state=42)
# X, y = undersampler.fit_resample(X, y)

# y.value_counts()
print(f"Shape dari matriks fitur X (setelah TF-IDF): {X.shape}")
print(f"Shape dari vektor target y: {y.shape}")

# Menampilkan jumlah fitur aktual yang digunakan
print(f"Jumlah fitur aktual yang digunakan oleh TF-IDF: {len(tfidf.get_feature_names_out())}")
print("\nContoh beberapa fitur teratas:")
print(list(tfidf.get_feature_names_out())[:20])
# Out:
# Shape dari matriks fitur X (setelah TF-IDF): (836, 937)
# Shape dari vektor target y: (836,)
# Jumlah fitur aktual yang digunakan oleh TF-IDF: 937
#
# Contoh beberapa fitur teratas:
# ['able', 'abu', 'accept', 'accepted', 'according', 'account', 'act', 'act worship', 'action', 'activist', 'activity', 'additionally', 'admin', 'admin post', 'ago', 'ah', 'ahead', 'ahmed', 'aid', 'al']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,  # 25% data digunakan untuk testing
    random_state=42,  # Untuk reproduktifitas hasil
    # stratify=y  # Mempertahankan proporsi kelas sentimen pada data training dan testing
)

print("Ukuran Data Setelah Pembagian:")
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

print("\nDistribusi kelas pada data training (proporsi):")
print(y_train.value_counts(normalize=True))
print(y_train.value_counts())

print("\nDistribusi kelas pada data testing (proporsi):")
print(y_test.value_counts(normalize=True))
print(y_test.value_counts())
# Out:
# Ukuran Data Setelah Pembagian:
# X_train shape: (668, 937), y_train shape: (668,)
# X_test shape: (168, 937), y_test shape: (168,)
#
# Distribusi kelas pada data training (proporsi):
# sentiment
# 1    0.52994
# 0    0.47006
# Name: proportion, dtype: float64
# sentiment
# 1    354
# 0    314
# Name: count, dtype: int64
#
# Distribusi kelas pada data testing (proporsi):
# sentiment
# 1    0.547619
# 0    0.452381
# Name: proportion, dtype: float64
# sentiment
# 1    92
# 0    76
# Name: count, dtype: int64

# %% [markdown]
# ## **Random forest**

# %%
rf = RandomForestClassifier(n_estimators=48, min_samples_leaf=1,min_samples_split= 9)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
# print("Train Accuracy:", np.mean(y_train == rf.predict(X_train)))
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7083333333333334

# %%
# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# ## **Pembeneran akurasi random forest**

# %%
best_acc = -1
for i in range(1, 3000, 25):
  # Menentukan jumlah fitur terbaik yang ingin dipilih
  # Anda bisa bereksperimen dengan nilai k ini (misal, 500, 1000, 2000, dll.)
  k_best_features = i # Jumlah fitur yang akan dipilih

  # Menggunakan SelectKBest dengan fungsi skor chi2
  # chi2 cocok untuk data non-negatif (seperti TF-IDF) dan target kategorikal
  selector = SelectKBest(score_func=chi2, k=k_best_features)

  # Melakukan pemilihan fitur pada data training (X dan y)
  # Penting: fit hanya pada data training untuk menghindari data leakage
  # Namun, karena SelectKBest/chi2 adalah metode filter (tidak bergantung pada model),
  # kita bisa fit pada seluruh X dan y sebelum split, lalu transform X_train dan X_test
  # (atau fit dan transform X_train, lalu transform X_test).
  # Untuk konsistensi dengan alur, mari kita fit pada X dan y sebelum split.
  # Nanti setelah split, kita akan transform X_train dan X_test.

  # Pastikan X dan y sudah terdefinisi dari tahap TF-IDF dan konversi label
  try:
      X_new = selector.fit_transform(X, y)

      print(f"\nShape matriks fitur sebelum pemilihan fitur: {X.shape}")
      print(f"Shape matriks fitur setelah pemilihan fitur (memilih {k_best_features} fitur terbaik): {X_new.shape}")

      # Mendapatkan nama fitur yang dipilih (opsional, tapi informatif)
      # Dapatkan indeks fitur yang dipilih
      selected_feature_indices = selector.get_support(indices=True)

      # Dapatkan nama fitur asli dari TfidfVectorizer (perlu diakses dari objek tfidf)
      # Pastikan objek tfidf dari cell sebelumnya masih tersedia
      try:
          original_feature_names = tfidf.get_feature_names_out()
          selected_feature_names = [original_feature_names[i] for i in selected_feature_indices]
          print(f"\nBeberapa contoh fitur yang dipilih ({len(selected_feature_names)} fitur):")
          # Tampilkan beberapa fitur pertama dan terakhir
          display(selected_feature_names[:10] + selected_feature_names[-10:])

      except NameError:
          print("\nObjek 'tfidf' dari tahap TF-IDF tidak ditemukan.")
          print("Tidak dapat menampilkan nama fitur yang dipilih.")
      except Exception as e:
          print(f"\nTerjadi error saat mendapatkan nama fitur: {e}")


  except NameError:
      print("\nError: Variabel X atau y belum terdefinisi dari tahap sebelumnya.")
      print("Pastikan Anda telah menjalankan cell 'Tahap Ekstraksi Fitur'.")

  X_train, X_test, y_train, y_test = train_test_split(
      X_new, y,
      test_size=0.2,  # 25% data digunakan untuk testing
      random_state=42,  # Untuk reproduktifitas hasil
      # stratify=y  # Mempertahankan proporsi kelas sentimen pada data training dan testing
  )

  rf = RandomForestClassifier(n_estimators=48, max_depth=80,min_samples_split=25,
                                 min_samples_leaf=1,
                                 class_weight='balanced', ccp_alpha=0)
  rf.fit(X_train, y_train)

  y_pred = rf.predict(X_test)

  accuracy = accuracy_score(y_test, y_pred)
  # print("Train Accuracy:", np.mean(y_train == rf.predict(X_train)))
  print(f"Accuracy: {accuracy}")
  if accuracy > best_acc:
    best_acc = accuracy
    k = i
print(f"Accuracybest: {best_acc}, k : {k}")
# Out:
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1 fitur terbaik): (836, 1)
#
# Beberapa contoh fitur yang dipilih (1 fitur):
# ['blessed', 'blessed']
# Accuracy: 0.5119047619047619
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 26 fitur terbaik): (836, 26)
#
# Beberapa contoh fitur yang dipilih (26 fitur):
# ['allah',
#  'beautiful',
#  'best',
#  'blessed',
#  'blessed month',
#  'blessed ramadan',
#  'blessing',
#  'bring',
#  'celebrate',
#  'celebrating',
#  'peace',
#  'peaceful',
#  'ramadan thread',
#  'ramadanmubarak',
#  'reward',
#  'soul',
#  'spiritual',
#  'try',
#  'wish',
#  'wishing']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 51 fitur terbaik): (836, 51)
#
# Beberapa contoh fitur yang dipilih (51 fitur):
# ['accept',
#  'allah',
#  'allah accept',
#  'amazing',
#  'arab',
#  'beautiful',
#  'best',
#  'bless',
#  'blessed',
#  'blessed month',
#  'ramadan thread',
#  'ramadanmubarak',
#  'reflection',
#  'reward',
#  'soul',
#  'special',
#  'spiritual',
#  'try',
#  'wish',
#  'wishing']
# Accuracy: 0.8035714285714286
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 76 fitur terbaik): (836, 76)
#
# Beberapa contoh fitur yang dipilih (76 fitur):
# ['accept',
#  'al',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'amazing',
#  'arab',
#  'bangladesh',
#  'beautiful',
#  'best',
#  'soul',
#  'special',
#  'spiritual',
#  'starmer',
#  'try',
#  'verse',
#  'vibe',
#  'wish',
#  'wishing',
#  'worship']
# Accuracy: 0.8273809523809523
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 101 fitur terbaik): (836, 101)
#
# Beberapa contoh fitur yang dipilih (101 fitur):
# ['accept',
#  'al',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allow',
#  'amazing',
#  'arab',
#  'bangladesh',
#  'beautiful',
#  'terrorist',
#  'tomorrow',
#  'try',
#  'verse',
#  'vibe',
#  'win',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'worship']
# Accuracy: 0.8273809523809523
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 126 fitur terbaik): (836, 126)
#
# Beberapa contoh fitur yang dipilih (126 fitur):
# ['accept',
#  'al',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allow',
#  'amazing',
#  'arab',
#  'bangladesh',
#  'beautiful',
#  'try',
#  'verse',
#  'vibe',
#  'win',
#  'windsor',
#  'windsor castle',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'worship']
# Accuracy: 0.8452380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 151 fitur terbaik): (836, 151)
#
# Beberapa contoh fitur yang dipilih (151 fitur):
# ['accept',
#  'al',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allow',
#  'amazing',
#  'arab',
#  'attack',
#  'bacon',
#  'verse',
#  'vibe',
#  'wednesday',
#  'win',
#  'windsor',
#  'windsor castle',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'worship']
# Accuracy: 0.8392857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 176 fitur terbaik): (836, 176)
#
# Beberapa contoh fitur yang dipilih (176 fitur):
# ['accept',
#  'al',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allow',
#  'amazing',
#  'arab',
#  'attack',
#  'verse',
#  'vibe',
#  'wednesday',
#  'win',
#  'windsor',
#  'windsor castle',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'worship']
# Accuracy: 0.8333333333333334
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 201 fitur terbaik): (836, 201)
#
# Beberapa contoh fitur yang dipilih (201 fitur):
# ['accept',
#  'al',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allow',
#  'amazing',
#  'ankalaev',
#  'arab',
#  'whilst',
#  'win',
#  'windsor',
#  'windsor castle',
#  'winner',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'worship',
#  'ya allah']
# Accuracy: 0.8214285714285714
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 226 fitur terbaik): (836, 226)
#
# Beberapa contoh fitur yang dipilih (226 fitur):
# ['accept',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allah allow',
#  'allah make',
#  'allow',
#  'whilst',
#  'win',
#  'windsor',
#  'windsor castle',
#  'winner',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'worship',
#  'ya allah']
# Accuracy: 0.8214285714285714
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 251 fitur terbaik): (836, 251)
#
# Beberapa contoh fitur yang dipilih (251 fitur):
# ['accept',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allah allow',
#  'allah make',
#  'win',
#  'windsor',
#  'windsor castle',
#  'winner',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'wonderful',
#  'worship',
#  'ya allah']
# Accuracy: 0.8452380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 276 fitur terbaik): (836, 276)
#
# Beberapa contoh fitur yang dipilih (276 fitur):
# ['accept',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'allah allow',
#  'allah make',
#  'windsor castle',
#  'winner',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8214285714285714
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 301 fitur terbaik): (836, 301)
#
# Beberapa contoh fitur yang dipilih (301 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'winner',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8511904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 326 fitur terbaik): (836, 326)
#
# Beberapa contoh fitur yang dipilih (326 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'allah accept',
#  'winner',
#  'wish',
#  'wishing',
#  'wishing blessed',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8571428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 351 fitur terbaik): (836, 351)
#
# Beberapa contoh fitur yang dipilih (351 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8333333333333334
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 376 fitur terbaik): (836, 376)
#
# Beberapa contoh fitur yang dipilih (376 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8392857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 401 fitur terbaik): (836, 401)
#
# Beberapa contoh fitur yang dipilih (401 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'allah',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8333333333333334
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 426 fitur terbaik): (836, 426)
#
# Beberapa contoh fitur yang dipilih (426 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alex pereira',
#  'alhamdulillah',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.7976190476190477
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 451 fitur terbaik): (836, 451)
#
# Beberapa contoh fitur yang dipilih (451 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'alex pereira',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8273809523809523
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 476 fitur terbaik): (836, 476)
#
# Beberapa contoh fitur yang dipilih (476 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'alex pereira',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8273809523809523
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 501 fitur terbaik): (836, 501)
#
# Beberapa contoh fitur yang dipilih (501 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'alex pereira',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.7916666666666666
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 526 fitur terbaik): (836, 526)
#
# Beberapa contoh fitur yang dipilih (526 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'ahead',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'wish muslim',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.8154761904761905
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 551 fitur terbaik): (836, 551)
#
# Beberapa contoh fitur yang dipilih (551 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'ahead',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'wishing',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'yesterday']
# Accuracy: 0.7857142857142857
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 576 fitur terbaik): (836, 576)
#
# Beberapa contoh fitur yang dipilih (576 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'ahead',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yesterday']
# Accuracy: 0.7738095238095238
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 601 fitur terbaik): (836, 601)
#
# Beberapa contoh fitur yang dipilih (601 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act',
#  'act worship',
#  'action',
#  'ago',
#  'ahead',
#  'aid',
#  'al',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yesterday',
#  'young']
# Accuracy: 0.8214285714285714
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 626 fitur terbaik): (836, 626)
#
# Beberapa contoh fitur yang dipilih (626 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act',
#  'act worship',
#  'action',
#  'ago',
#  'ahead',
#  'aid',
#  'al',
#  'wishing observing',
#  'witness',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yesterday',
#  'young']
# Accuracy: 0.7976190476190477
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 651 fitur terbaik): (836, 651)
#
# Beberapa contoh fitur yang dipilih (651 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act',
#  'act worship',
#  'action',
#  'ago',
#  'ahead',
#  'aid',
#  'al',
#  'witness',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'young']
# Accuracy: 0.8095238095238095
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 676 fitur terbaik): (836, 676)
#
# Beberapa contoh fitur yang dipilih (676 fitur):
# ['abu',
#  'accept',
#  'accepted',
#  'according',
#  'act',
#  'act worship',
#  'action',
#  'ago',
#  'ahead',
#  'aid',
#  'wonderful',
#  'word',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'young']
# Accuracy: 0.7559523809523809
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 701 fitur terbaik): (836, 701)
#
# Beberapa contoh fitur yang dipilih (701 fitur):
# ['abu',
#  'accept',
#  'accepted',
#  'according',
#  'act',
#  'act worship',
#  'action',
#  'additionally',
#  'ago',
#  'ahead',
#  'working',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 726 fitur terbaik): (836, 726)
#
# Beberapa contoh fitur yang dipilih (726 fitur):
# ['abu',
#  'accept',
#  'accepted',
#  'according',
#  'act',
#  'act worship',
#  'action',
#  'additionally',
#  'ago',
#  'ahead',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7738095238095238
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 751 fitur terbaik): (836, 751)
#
# Beberapa contoh fitur yang dipilih (751 fitur):
# ['abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activity',
#  'additionally',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 776 fitur terbaik): (836, 776)
#
# Beberapa contoh fitur yang dipilih (776 fitur):
# ['abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activity',
#  'additionally',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7559523809523809
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 801 fitur terbaik): (836, 801)
#
# Beberapa contoh fitur yang dipilih (801 fitur):
# ['abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activity',
#  'additionally',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7619047619047619
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 826 fitur terbaik): (836, 826)
#
# Beberapa contoh fitur yang dipilih (826 fitur):
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activity',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7738095238095238
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 851 fitur terbaik): (836, 851)
#
# Beberapa contoh fitur yang dipilih (851 fitur):
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activity',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 876 fitur terbaik): (836, 876)
#
# Beberapa contoh fitur yang dipilih (876 fitur):
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activity',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 901 fitur terbaik): (836, 901)
#
# Beberapa contoh fitur yang dipilih (901 fitur):
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 926 fitur terbaik): (836, 926)
#
# Beberapa contoh fitur yang dipilih (926 fitur):
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 951 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=951 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 976 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=976 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1001 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1001 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1026 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1026 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7023809523809523
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1051 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1051 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1076 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1076 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7202380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1101 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1101 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1126 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1126 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1151 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1151 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1176 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1176 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1201 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1201 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7142857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1226 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1226 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.6964285714285714
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1251 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1251 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7142857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1276 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1276 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7142857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1301 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1301 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7023809523809523
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1326 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1326 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1351 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1351 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1376 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1376 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1401 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1401 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1426 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1426 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1451 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1451 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1476 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1476 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1501 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1501 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1526 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1526 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7202380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1551 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1551 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1576 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1576 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1601 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1601 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7202380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1626 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1626 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1651 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1651 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1676 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1676 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1701 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1701 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1726 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1726 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7619047619047619
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1751 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1751 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1776 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1776 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1801 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1801 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7142857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1826 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1826 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7619047619047619
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1851 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1851 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1876 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1876 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1901 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1901 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1926 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1926 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1951 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1951 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 1976 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=1976 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2001 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2001 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2026 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2026 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7619047619047619
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2051 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2051 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2076 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2076 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2101 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2101 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
# ...
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7202380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2401 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2401 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2426 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2426 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2451 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2451 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2476 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2476 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2501 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2501 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2526 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2526 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2551 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2551 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2576 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2576 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2601 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2601 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.75
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2626 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2626 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7321428571428571
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2651 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2651 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7083333333333334
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2676 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2676 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7619047619047619
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2701 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2701 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2726 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2726 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7202380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2751 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2751 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2776 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2776 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7380952380952381
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2801 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2801 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7678571428571429
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2826 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2826 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7559523809523809
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2851 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2851 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2876 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2876 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7261904761904762
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2901 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2901 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2926 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2926 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7202380952380952
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2951 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2951 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7142857142857143
#
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 2976 fitur terbaik): (836, 937)
#
# Beberapa contoh fitur yang dipilih (937 fitur):
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:783: UserWarning: k=2976 is greater than n_features=937. All the features will be returned.
#   warnings.warn(
# ['able',
#  'abu',
#  'accept',
#  'accepted',
#  'according',
#  'account',
#  'act',
#  'act worship',
#  'action',
#  'activist',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'year old',
#  'yes',
#  'yesterday',
#  'york',
#  'young']
# Accuracy: 0.7440476190476191
# Accuracybest: 0.8571428571428571, k : 326

# %%
rf
# Out:
# RandomForestClassifier(ccp_alpha=0, class_weight='balanced', max_depth=80,
#                        min_samples_split=25, n_estimators=48)

# %%
# Menentukan jumlah fitur terbaik yang ingin dipilih
# Anda bisa bereksperimen dengan nilai k ini (misal, 500, 1000, 2000, dll.)
k_best_features = 576 # Jumlah fitur yang akan dipilih

# Menggunakan SelectKBest dengan fungsi skor chi2
# chi2 cocok untuk data non-negatif (seperti TF-IDF) dan target kategorikal
selector = SelectKBest(score_func=chi2, k=k_best_features)

# Melakukan pemilihan fitur pada data training (X dan y)
# Penting: fit hanya pada data training untuk menghindari data leakage
# Namun, karena SelectKBest/chi2 adalah metode filter (tidak bergantung pada model),
# kita bisa fit pada seluruh X dan y sebelum split, lalu transform X_train dan X_test
# (atau fit dan transform X_train, lalu transform X_test).
# Untuk konsistensi dengan alur, mari kita fit pada X dan y sebelum split.
# Nanti setelah split, kita akan transform X_train dan X_test.

# Pastikan X dan y sudah terdefinisi dari tahap TF-IDF dan konversi label
try:
    X_new = selector.fit_transform(X, y)

    print(f"\nShape matriks fitur sebelum pemilihan fitur: {X.shape}")
    print(f"Shape matriks fitur setelah pemilihan fitur (memilih {k_best_features} fitur terbaik): {X_new.shape}")

    # Mendapatkan nama fitur yang dipilih (opsional, tapi informatif)
    # Dapatkan indeks fitur yang dipilih
    selected_feature_indices = selector.get_support(indices=True)

    # Dapatkan nama fitur asli dari TfidfVectorizer (perlu diakses dari objek tfidf)
    # Pastikan objek tfidf dari cell sebelumnya masih tersedia
    try:
        original_feature_names = tfidf.get_feature_names_out()
        selected_feature_names = [original_feature_names[i] for i in selected_feature_indices]
        print(f"\nBeberapa contoh fitur yang dipilih ({len(selected_feature_names)} fitur):")
        # Tampilkan beberapa fitur pertama dan terakhir
        display(selected_feature_names[:10] + selected_feature_names[-10:])

    except NameError:
        print("\nObjek 'tfidf' dari tahap TF-IDF tidak ditemukan.")
        print("Tidak dapat menampilkan nama fitur yang dipilih.")
    except Exception as e:
        print(f"\nTerjadi error saat mendapatkan nama fitur: {e}")


except NameError:
    print("\nError: Variabel X atau y belum terdefinisi dari tahap sebelumnya.")
    print("Pastikan Anda telah menjalankan cell 'Tahap Ekstraksi Fitur'.")

# smote=SMOTE(sampling_strategy='auto')
# X_new,y=smote.fit_resample(X_new,y)
# from imblearn.under_sampling import RandomUnderSampler

# undersampler = RandomUnderSampler(sampling_strategy='majority', random_state=42)
# X, y = undersampler.fit_resample(X, y)
# Sekarang, variabel fitur yang akan digunakan untuk split data adalah X_new
# Tahap selanjutnya (Pembagian Data) harus menggunakan X_new dan y

X_train, X_test, y_train, y_test = train_test_split(
    X_new, y,
    test_size=0.2,  # 25% data digunakan untuk testing
    random_state=42,  # Untuk reproduktifitas hasil
    stratify=y  # Mempertahankan proporsi kelas sentimen pada data training dan testing
)

rf = RandomForestClassifier(n_estimators=48, max_depth=None,min_samples_split=25,
                                 min_samples_leaf=1,
                                 class_weight='balanced', ccp_alpha=0)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
# print("Train Accuracy:", np.mean(y_train == rf.predict(X_train)))
print(f"Accuracy: {accuracy}")
# Out:
# Shape matriks fitur sebelum pemilihan fitur: (836, 937)
# Shape matriks fitur setelah pemilihan fitur (memilih 576 fitur terbaik): (836, 576)
#
# Beberapa contoh fitur yang dipilih (576 fitur):
# ['accept',
#  'accepted',
#  'according',
#  'act worship',
#  'action',
#  'ahead',
#  'aid',
#  'al',
#  'alaqsamosque',
#  'alaqsamosque ramadan',
#  'wishing blessed',
#  'wishing muslim',
#  'wishing observing',
#  'wonderful',
#  'world blessed',
#  'worship',
#  'ya',
#  'ya allah',
#  'year',
#  'yesterday']
# Accuracy: 0.7678571428571429

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_new, y,
    test_size=0.2,  # 25% data digunakan untuk testing
    random_state=42,  # Untuk reproduktifitas hasil
    # stratify=y  # Mempertahankan proporsi kelas sentimen pada data training dan testing
)

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Train Accuracy:", np.mean(y_train == rf.predict(X_train)))
print(f"Testing Accuracy: {accuracy}")
# Out:
# Train Accuracy: 0.9859747545582047
# Testing Accuracy: 0.8212290502793296

# %%
rf
# Out:
# RandomForestClassifier()

# %%
# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %%
# rf = RandomForestClassifier(n_estimators=1000, min_samples_leaf=1, min_samples_split=20, max_depth=None)
rf = RandomForestClassifier(n_estimators=48, max_depth=None,min_samples_split=25,
                                 min_samples_leaf=1,
                                 class_weight='balanced', ccp_alpha=0)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Train Accuracy:", np.mean(y_train == rf.predict(X_train)))
print(f"Accuracy: {accuracy}")
# Out:
# Train Accuracy: 0.9621318373071529
# Accuracy: 0.8100558659217877

# %%
# best_model.get_params()

# %%
# rf.get_params()

# %%
rf_grid = RandomForestClassifier(n_estimators=48, max_depth=None)
gr_space = {
    # 'max_depth': [3,5,7,10],
    # 'n_estimators': [100, 200, 300, 400, 500],
    # 'max_features': [10, 20, 30 , 40],
    # 'min_samples_leaf': [1, 2, 4]
    # 'max_depth': [2, 3, 5, 10, 20, 25],
    # 'min_samples_leaf': [2, 5, 10, 20, 50, 100],
    'criterion': ['entropy'],
    'min_samples_split': list(range(2, 21)),
    'min_samples_leaf': [1, 2, 3, 4,5, 6,7, 8],    # Perluas sedikit
}

grid = GridSearchCV(rf_grid, gr_space, cv = 3, scoring='accuracy', verbose = 3)
model_grid = grid.fit(X_train, y_train)
# Create a variable for the best model
best_rf = model_grid.best_estimator_
y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print('Best hyperparameters are '+str(model_grid.best_params_))
print('Best score is: ' + str(model_grid.best_score_))

print("\nTrain Accuracy:", np.mean(y_train == best_rf.predict(X_train)))
print("Test Accuracy:", accuracy)
# Out:
# Fitting 3 folds for each of 152 candidates, totalling 456 fits
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=2;, score=0.758 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=2;, score=0.789 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=2;, score=0.671 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=3;, score=0.771 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=3;, score=0.785 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=3;, score=0.676 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=4;, score=0.771 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=4;, score=0.771 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=4;, score=0.676 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=5;, score=0.780 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=5;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=5;, score=0.689 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=6;, score=0.771 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=6;, score=0.798 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=6;, score=0.662 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=7;, score=0.767 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=7;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=7;, score=0.680 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=8;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=8;, score=0.789 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=8;, score=0.671 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=9;, score=0.758 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=9;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=9;, score=0.671 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=10;, score=0.785 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=10;, score=0.776 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=10;, score=0.667 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=11;, score=0.767 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=11;, score=0.780 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=11;, score=0.671 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=12;, score=0.758 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=12;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=12;, score=0.676 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=13;, score=0.785 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=13;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=13;, score=0.676 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=14;, score=0.776 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=14;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=14;, score=0.680 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=15;, score=0.771 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=15;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=15;, score=0.703 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=16;, score=0.780 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=16;, score=0.785 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=16;, score=0.689 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=17;, score=0.776 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=17;, score=0.789 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=17;, score=0.671 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=18;, score=0.776 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=18;, score=0.780 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=18;, score=0.703 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=19;, score=0.771 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=19;, score=0.794 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=19;, score=0.685 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=20;, score=0.785 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=20;, score=0.789 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=1, min_samples_split=20;, score=0.703 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=2;, score=0.758 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=2;, score=0.731 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=2;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=3;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=3;, score=0.753 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=3;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=4;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=4;, score=0.744 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=4;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=5;, score=0.767 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=5;, score=0.758 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=5;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=6;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=6;, score=0.749 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=6;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=7;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=7;, score=0.749 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=7;, score=0.631 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=8;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=8;, score=0.749 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=8;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=9;, score=0.758 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=9;, score=0.740 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=9;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=10;, score=0.767 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=10;, score=0.762 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=10;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=11;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=11;, score=0.744 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=11;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=12;, score=0.758 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=12;, score=0.753 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=12;, score=0.631 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=13;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=13;, score=0.758 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=13;, score=0.626 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=14;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=14;, score=0.735 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=14;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=15;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=15;, score=0.744 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=15;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=16;, score=0.762 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=16;, score=0.758 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=16;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=17;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=17;, score=0.744 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=17;, score=0.658 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=18;, score=0.762 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=18;, score=0.744 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=18;, score=0.635 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=19;, score=0.753 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=19;, score=0.762 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=19;, score=0.631 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=20;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=20;, score=0.744 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=2, min_samples_split=20;, score=0.649 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=2;, score=0.740 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=2;, score=0.740 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=2;, score=0.653 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=3;, score=0.735 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=3;, score=0.735 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=3;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=4;, score=0.735 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=4;, score=0.726 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=4;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=5;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=5;, score=0.731 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=5;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=6;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=6;, score=0.726 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=6;, score=0.671 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=7;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=7;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=7;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=8;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=8;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=8;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=9;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=9;, score=0.731 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=9;, score=0.671 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=10;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=10;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=10;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=11;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=11;, score=0.735 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=11;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=12;, score=0.713 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=12;, score=0.726 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=12;, score=0.622 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=13;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=13;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=13;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=14;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=14;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=14;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=15;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=15;, score=0.726 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=15;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=16;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=16;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=16;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=17;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=17;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=17;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=18;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=18;, score=0.726 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=18;, score=0.626 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=19;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=19;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=19;, score=0.631 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=20;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=20;, score=0.731 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=3, min_samples_split=20;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=2;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=2;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=2;, score=0.617 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=3;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=3;, score=0.704 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=3;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=4;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=4;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=4;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=5;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=5;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=5;, score=0.626 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=6;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=6;, score=0.726 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=6;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=7;, score=0.758 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=7;, score=0.700 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=7;, score=0.622 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=8;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=8;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=8;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=9;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=9;, score=0.704 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=9;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=10;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=10;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=10;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=11;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=11;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=11;, score=0.622 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=12;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=12;, score=0.735 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=12;, score=0.617 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=13;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=13;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=13;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=14;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=14;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=14;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=15;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=15;, score=0.700 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=15;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=16;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=16;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=16;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=17;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=17;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=17;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=18;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=18;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=18;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=19;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=19;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=19;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=20;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=20;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=4, min_samples_split=20;, score=0.644 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=2;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=2;, score=0.700 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=2;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=3;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=3;, score=0.717 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=3;, score=0.635 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=4;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=4;, score=0.704 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=4;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=5;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=5;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=5;, score=0.622 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=6;, score=0.717 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=6;, score=0.713 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=6;, score=0.640 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=7;, score=0.700 total time=   0.2s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=7;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=7;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=8;, score=0.704 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=8;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=8;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=9;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=9;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=9;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=10;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=10;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=10;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=11;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=11;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=11;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=12;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=12;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=12;, score=0.662 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=13;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=13;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=13;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=14;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=14;, score=0.704 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=14;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=15;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=15;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=15;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=16;, score=0.709 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=16;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=16;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=17;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=17;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=17;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=18;, score=0.713 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=18;, score=0.700 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=18;, score=0.626 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=19;, score=0.713 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=19;, score=0.700 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=19;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=20;, score=0.740 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=20;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=5, min_samples_split=20;, score=0.608 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=2;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=2;, score=0.686 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=2;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=3;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=3;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=3;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=4;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=4;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=4;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=5;, score=0.744 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=5;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=5;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=6;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=6;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=6;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=7;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=7;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=7;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=8;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=8;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=8;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=9;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=9;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=9;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=10;, score=0.700 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=10;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=10;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=11;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=11;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=11;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=12;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=12;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=12;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=13;, score=0.713 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=13;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=13;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=14;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=14;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=14;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=15;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=15;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=15;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=16;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=16;, score=0.704 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=16;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=17;, score=0.704 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=17;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=17;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=18;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=18;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=18;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=19;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=19;, score=0.695 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=19;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=20;, score=0.753 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=20;, score=0.722 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=6, min_samples_split=20;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=2;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=2;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=2;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=3;, score=0.735 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=3;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=3;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=4;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=4;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=4;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=5;, score=0.731 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=5;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=5;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=6;, score=0.709 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=6;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=6;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=7;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=7;, score=0.713 total time=   0.2s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=7;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=8;, score=0.570 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=8;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=8;, score=0.662 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=9;, score=0.722 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=9;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=9;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=10;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=10;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=10;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=11;, score=0.713 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=11;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=11;, score=0.649 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=12;, score=0.749 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=12;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=12;, score=0.635 total time=   0.2s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=13;, score=0.561 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=13;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=13;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=14;, score=0.695 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=14;, score=0.700 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=14;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=15;, score=0.704 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=15;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=15;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=16;, score=0.709 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=16;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=16;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=17;, score=0.587 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=17;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=17;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=18;, score=0.691 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=18;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=18;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=19;, score=0.578 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=19;, score=0.704 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=19;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=20;, score=0.717 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=20;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=7, min_samples_split=20;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=2;, score=0.677 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=2;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=2;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=3;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=3;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=3;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=4;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=4;, score=0.677 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=4;, score=0.631 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=5;, score=0.570 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=5;, score=0.686 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=5;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=6;, score=0.726 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=6;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=6;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=7;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=7;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=7;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=8;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=8;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=8;, score=0.635 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=9;, score=0.552 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=9;, score=0.713 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=9;, score=0.662 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=10;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=10;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=10;, score=0.631 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=11;, score=0.700 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=11;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=11;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=12;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=12;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=12;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=13;, score=0.534 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=13;, score=0.717 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=13;, score=0.658 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=14;, score=0.552 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=14;, score=0.691 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=14;, score=0.662 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=15;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=15;, score=0.709 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=15;, score=0.649 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=16;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=16;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=16;, score=0.640 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=17;, score=0.543 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=17;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=17;, score=0.631 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=18;, score=0.700 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=18;, score=0.534 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=18;, score=0.653 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=19;, score=0.529 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=19;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=19;, score=0.644 total time=   0.1s
# [CV 1/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=20;, score=0.534 total time=   0.1s
# [CV 2/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=20;, score=0.529 total time=   0.1s
# [CV 3/3] END criterion=entropy, min_samples_leaf=8, min_samples_split=20;, score=0.631 total time=   0.1s
# Best hyperparameters are {'criterion': 'entropy', 'min_samples_leaf': 1, 'min_samples_split': 20}
# Best score is: 0.758897911364279
#
# Train Accuracy: 0.8458083832335329
# Test Accuracy: 0.8273809523809523

# %%
param_dist = {
    'n_estimators': randint(50,500),
    # 'max_depth': randint(1,20),

              'min_samples_leaf': randint(1, 4),
              'min_samples_split': randint(2, 30),
              # 'max_features': ['auto', 'sqrt', 'log2'],
              # 'criterion': ['gini', 'entropy']
    }

# Create a random forest classifier
rf = RandomForestClassifier(n_estimators=48, max_depth=None)

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(rf,
                                 param_distributions = param_dist,
                                 n_iter=100,
                                 cv=5,
                                 n_jobs=-1,
                                 verbose=5,
                                #  scoring='accuracy'
                                 )

# Fit the random search object to the data
rand_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=48),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x782d5e83f990>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x782d5d864990>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x782d5bbd9fd0>},
#                    verbose=5)

# %%
# Create a variable for the best model
best_rf = rand_search.best_estimator_

y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)

print("Train Accuracy:", np.mean(y_train == best_rf.predict(X_train)))
print("Test Accuracy:", accuracy)
# Out:
# Best hyperparameters: {'min_samples_leaf': 1, 'min_samples_split': 13, 'n_estimators': 414}
# Train Accuracy: 0.9431137724550899
# Test Accuracy: 0.8511904761904762

# %%
# INI BIAR GA KEHAPUS BEST ACC
param_dist = {
    'n_estimators': randint(50,500),
    # 'max_depth': randint(1,20),

              # 'min_samples_leaf': randint(1, 4),
              # 'min_samples_split': randint(2, 30),
              # 'max_features': ['auto', 'sqrt', 'log2'],
              # 'criterion': ['gini', 'entropy']
    }

# Create a random forest classifier
rf = RandomForestClassifier(n_estimators=48, max_depth=None,min_samples_split=25,
                                 min_samples_leaf=1,
                                 class_weight='balanced', ccp_alpha=0)

# Use random search to find the best hyperparameters
rand_search = RandomizedSearchCV(rf,
                                 param_distributions = param_dist,
                                 n_iter=10,
                                 cv=5,
                                 n_jobs=-1,
                                 verbose=5,
                                #  scoring='accuracy'
                                 )

# Fit the random search object to the data
rand_search.fit(X_train, y_train)
# Create a variable for the best model
best_rf = rand_search.best_estimator_

y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
# Print the best hyperparameters
print('Best hyperparameters:',  rand_search.best_params_)

print("Train Accuracy:", np.mean(y_train == best_rf.predict(X_train)))
print("Test Accuracy:", accuracy)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best hyperparameters: {'n_estimators': 393}
# Train Accuracy: 0.9312762973352033
# Test Accuracy: 0.8547486033519553

# %%
Test Accuracy: 0.8392857142857143

# %%
best_model = None
best_acc = -1

# max_depth= [2, 3, 5, 10, 20, 25]
min_samples_leaf_ar= [1, 2, 3, 4,5, 6,7, 8]    # Perluas sedikit
min_samples_split_ar = list(range(2, 21))
# ccp_alpha_ar = [0.0, 0.001, 0.005, 0.01]
# criterion = ['gini', 'entropy', 'log_loss']
# splitter = ['best', 'random']
# min_weight_fraction_leaf = [0.0, 0.01, 0.05]
# max_features = [None, 'sqrt', 'log2']
# max_leaf_nodes = [None, 10, 20, 50, 100]
# min_impurity_decrease = [0.0, 0.01, 0.1]
# class_weight = [None, 'balanced']

# for max_depth in max_depth:
for min_samples_leaf in min_samples_leaf_ar:
  for min_samples_split in min_samples_split_ar:
    # for ccp_alpha in ccp_alpha_ar:
    for i in range(5):

      # print(f"\nmax_depth : {max_depth}")
      print(f"\nmin_samples_leaf : {min_samples_leaf}")
      print(f"min_samples_split : {min_samples_split}")
      # print(f"ccp : {ccp_alpha}")
      # Create the Decision Tree model with given parameters
      model = RandomForestClassifier(n_estimators=414,
                                      max_depth=None,
                                      min_samples_leaf=min_samples_leaf,
                                      min_samples_split=min_samples_split)

      # Train the model
      model.fit(X_train, y_train)

      # Predict on the test set
      y_pred = model.predict(X_test)

      # Calculate accuracy
      # Predictions
      train_preds = model.predict(X_train)
      test_preds = model.predict(X_test)

      # Accuracy scores
      train_accuracy = accuracy_score(y_train, train_preds)
      test_accuracy = accuracy_score(y_test, test_preds)

      print("Training Accuracy:", train_accuracy)
      print("Test Accuracy:", test_accuracy)
      if test_accuracy > best_acc:
        best_model = model
        best_acc = test_accuracy
train_accuracy = accuracy_score(y_train, best_model.predict(X_train))
print("\n\nTraining Accuracy:", train_accuracy)
print(f"Akurasi plg bagus : {best_acc}")
# Out:
# min_samples_leaf : 1
# min_samples_split : 2
# Training Accuracy: 0.9452991452991453
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 1
# min_samples_split : 2
# Training Accuracy: 0.947008547008547
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 2
# Training Accuracy: 0.9435897435897436
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 2
# Training Accuracy: 0.9487179487179487
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 2
# Training Accuracy: 0.9504273504273504
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 3
# Training Accuracy: 0.9487179487179487
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 1
# min_samples_split : 3
# Training Accuracy: 0.9435897435897436
# Test Accuracy: 0.7808764940239044
#
# min_samples_leaf : 1
# min_samples_split : 3
# Training Accuracy: 0.9452991452991453
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 3
# Training Accuracy: 0.9435897435897436
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 3
# Training Accuracy: 0.9452991452991453
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 4
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 4
# Training Accuracy: 0.9418803418803419
# Test Accuracy: 0.7888446215139442
#
# min_samples_leaf : 1
# min_samples_split : 4
# Training Accuracy: 0.9435897435897436
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 4
# Training Accuracy: 0.9384615384615385
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 4
# Training Accuracy: 0.9401709401709402
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 5
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 1
# min_samples_split : 5
# Training Accuracy: 0.9384615384615385
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 5
# Training Accuracy: 0.9367521367521368
# Test Accuracy: 0.7808764940239044
#
# min_samples_leaf : 1
# min_samples_split : 5
# Training Accuracy: 0.9367521367521368
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 5
# Training Accuracy: 0.9401709401709402
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 6
# Training Accuracy: 0.9247863247863248
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 1
# min_samples_split : 6
# Training Accuracy: 0.935042735042735
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 1
# min_samples_split : 6
# Training Accuracy: 0.9401709401709402
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 1
# min_samples_split : 6
# Training Accuracy: 0.9401709401709402
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 6
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 7
# Training Accuracy: 0.9384615384615385
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 7
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 1
# min_samples_split : 7
# Training Accuracy: 0.935042735042735
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 7
# Training Accuracy: 0.9299145299145299
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 1
# min_samples_split : 7
# Training Accuracy: 0.9367521367521368
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 8
# Training Accuracy: 0.9367521367521368
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 8
# Training Accuracy: 0.9213675213675213
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 1
# min_samples_split : 8
# Training Accuracy: 0.9299145299145299
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 8
# Training Accuracy: 0.9401709401709402
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 1
# min_samples_split : 8
# Training Accuracy: 0.9282051282051282
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 1
# min_samples_split : 9
# Training Accuracy: 0.9230769230769231
# Test Accuracy: 0.7689243027888446
#
# min_samples_leaf : 1
# min_samples_split : 9
# Training Accuracy: 0.9452991452991453
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 9
# Training Accuracy: 0.9247863247863248
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 9
# Training Accuracy: 0.9299145299145299
# Test Accuracy: 0.7768924302788844
#
# min_samples_leaf : 1
# min_samples_split : 9
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7729083665338645
#
# min_samples_leaf : 1
# min_samples_split : 10
# Training Accuracy: 0.9384615384615385
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 10
# Training Accuracy: 0.9367521367521368
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 10
# Training Accuracy: 0.9282051282051282
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 10
# Training Accuracy: 0.9247863247863248
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 10
# Training Accuracy: 0.935042735042735
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 1
# min_samples_split : 11
# Training Accuracy: 0.9196581196581196
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 11
# Training Accuracy: 0.9213675213675213
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 11
# Training Accuracy: 0.9316239316239316
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 11
# Training Accuracy: 0.9299145299145299
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 11
# Training Accuracy: 0.9299145299145299
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 12
# Training Accuracy: 0.9179487179487179
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 12
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 12
# Training Accuracy: 0.9247863247863248
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 1
# min_samples_split : 12
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 12
# Training Accuracy: 0.9282051282051282
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 13
# Training Accuracy: 0.9316239316239316
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 13
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 1
# min_samples_split : 13
# Training Accuracy: 0.9316239316239316
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 1
# min_samples_split : 13
# Training Accuracy: 0.9247863247863248
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 1
# min_samples_split : 13
# Training Accuracy: 0.9316239316239316
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 14
# Training Accuracy: 0.9299145299145299
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 1
# min_samples_split : 14
# Training Accuracy: 0.9162393162393162
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 1
# min_samples_split : 14
# Training Accuracy: 0.9230769230769231
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 1
# min_samples_split : 14
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 14
# Training Accuracy: 0.9264957264957265
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 15
# Training Accuracy: 0.9230769230769231
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 15
# Training Accuracy: 0.9179487179487179
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 15
# Training Accuracy: 0.9264957264957265
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 1
# min_samples_split : 15
# Training Accuracy: 0.9230769230769231
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 15
# Training Accuracy: 0.9333333333333333
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 16
# Training Accuracy: 0.9213675213675213
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 16
# Training Accuracy: 0.9162393162393162
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 16
# Training Accuracy: 0.9213675213675213
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 1
# min_samples_split : 16
# Training Accuracy: 0.9282051282051282
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 16
# Training Accuracy: 0.9230769230769231
# Test Accuracy: 0.7689243027888446
#
# min_samples_leaf : 1
# min_samples_split : 17
# Training Accuracy: 0.9145299145299145
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 17
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 1
# min_samples_split : 17
# Training Accuracy: 0.9179487179487179
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 17
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7729083665338645
#
# min_samples_leaf : 1
# min_samples_split : 17
# Training Accuracy: 0.9196581196581196
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 1
# min_samples_split : 18
# Training Accuracy: 0.9196581196581196
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 18
# Training Accuracy: 0.9179487179487179
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 1
# min_samples_split : 18
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 1
# min_samples_split : 18
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 18
# Training Accuracy: 0.9282051282051282
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 1
# min_samples_split : 19
# Training Accuracy: 0.9179487179487179
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 19
# Training Accuracy: 0.9162393162393162
# Test Accuracy: 0.7768924302788844
#
# min_samples_leaf : 1
# min_samples_split : 19
# Training Accuracy: 0.9145299145299145
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 1
# min_samples_split : 19
# Training Accuracy: 0.9196581196581196
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 19
# Training Accuracy: 0.9213675213675213
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 1
# min_samples_split : 20
# Training Accuracy: 0.9196581196581196
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 1
# min_samples_split : 20
# Training Accuracy: 0.9179487179487179
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 1
# min_samples_split : 20
# Training Accuracy: 0.9213675213675213
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 1
# min_samples_split : 20
# Training Accuracy: 0.9162393162393162
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 1
# min_samples_split : 20
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 2
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 2
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 2
# Training Accuracy: 0.8974358974358975
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 2
# min_samples_split : 2
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 2
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 2
# min_samples_split : 3
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 3
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7689243027888446
#
# min_samples_leaf : 2
# min_samples_split : 3
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 3
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 3
# Training Accuracy: 0.8974358974358975
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 4
# Training Accuracy: 0.9042735042735043
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 2
# min_samples_split : 4
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 2
# min_samples_split : 4
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 4
# Training Accuracy: 0.8991452991452992
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 4
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 5
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 5
# Training Accuracy: 0.8991452991452992
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 5
# Training Accuracy: 0.9042735042735043
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 5
# Training Accuracy: 0.9196581196581196
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 5
# Training Accuracy: 0.8957264957264958
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 6
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 6
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 6
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 6
# Training Accuracy: 0.9230769230769231
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 6
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 7
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7808764940239044
#
# min_samples_leaf : 2
# min_samples_split : 7
# Training Accuracy: 0.8957264957264958
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 7
# Training Accuracy: 0.8940170940170941
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 7
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 7
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 8
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 2
# min_samples_split : 8
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 8
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 8
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 8
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 2
# min_samples_split : 9
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 9
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 9
# Training Accuracy: 0.8923076923076924
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 9
# Training Accuracy: 0.8888888888888888
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 9
# Training Accuracy: 0.8991452991452992
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 10
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 10
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 10
# Training Accuracy: 0.8957264957264958
# Test Accuracy: 0.7808764940239044
#
# min_samples_leaf : 2
# min_samples_split : 10
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 10
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 11
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 11
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 11
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 2
# min_samples_split : 11
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 11
# Training Accuracy: 0.8991452991452992
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 2
# min_samples_split : 12
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 2
# min_samples_split : 12
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 2
# min_samples_split : 12
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 12
# Training Accuracy: 0.8974358974358975
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 2
# min_samples_split : 12
# Training Accuracy: 0.8923076923076924
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 2
# min_samples_split : 13
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 13
# Training Accuracy: 0.8940170940170941
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 2
# min_samples_split : 13
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 13
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 2
# min_samples_split : 13
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 14
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 14
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 14
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 2
# min_samples_split : 14
# Training Accuracy: 0.8923076923076924
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 14
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 2
# min_samples_split : 15
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 2
# min_samples_split : 15
# Training Accuracy: 0.9042735042735043
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 15
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 15
# Training Accuracy: 0.9042735042735043
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 15
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 16
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 16
# Training Accuracy: 0.9076923076923077
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 16
# Training Accuracy: 0.9145299145299145
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 16
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 2
# min_samples_split : 16
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 17
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 17
# Training Accuracy: 0.9111111111111111
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 17
# Training Accuracy: 0.9042735042735043
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 17
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 2
# min_samples_split : 17
# Training Accuracy: 0.9042735042735043
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 2
# min_samples_split : 18
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 2
# min_samples_split : 18
# Training Accuracy: 0.8923076923076924
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 18
# Training Accuracy: 0.9128205128205128
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 18
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 2
# min_samples_split : 18
# Training Accuracy: 0.8923076923076924
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 2
# min_samples_split : 19
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 19
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 19
# Training Accuracy: 0.905982905982906
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 19
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 19
# Training Accuracy: 0.8923076923076924
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 2
# min_samples_split : 20
# Training Accuracy: 0.9008547008547009
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 20
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 20
# Training Accuracy: 0.9094017094017094
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 2
# min_samples_split : 20
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 2
# min_samples_split : 20
# Training Accuracy: 0.9025641025641026
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 2
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 3
# min_samples_split : 2
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 2
# Training Accuracy: 0.8581196581196581
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 2
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 2
# Training Accuracy: 0.8564102564102564
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 3
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 3
# Training Accuracy: 0.8598290598290599
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 3
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 3
# Training Accuracy: 0.8717948717948718
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 3
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 4
# Training Accuracy: 0.8598290598290599
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 4
# Training Accuracy: 0.882051282051282
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 4
# Training Accuracy: 0.8871794871794871
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 4
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 4
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 5
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 5
# Training Accuracy: 0.8717948717948718
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 3
# min_samples_split : 5
# Training Accuracy: 0.8581196581196581
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 5
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 5
# Training Accuracy: 0.8752136752136752
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 6
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 3
# min_samples_split : 6
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 6
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 6
# Training Accuracy: 0.8512820512820513
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 6
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 7
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 3
# min_samples_split : 7
# Training Accuracy: 0.8598290598290599
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 3
# min_samples_split : 7
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 3
# min_samples_split : 7
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 7
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 3
# min_samples_split : 8
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 8
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 8
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 8
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 8
# Training Accuracy: 0.8581196581196581
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 9
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 3
# min_samples_split : 9
# Training Accuracy: 0.8512820512820513
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 3
# min_samples_split : 9
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 9
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 9
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 10
# Training Accuracy: 0.8752136752136752
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 3
# min_samples_split : 10
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 10
# Training Accuracy: 0.8495726495726496
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 10
# Training Accuracy: 0.8512820512820513
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 10
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 11
# Training Accuracy: 0.852991452991453
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 11
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 11
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 3
# min_samples_split : 11
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 11
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 12
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 3
# min_samples_split : 12
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 12
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 12
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 3
# min_samples_split : 12
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 13
# Training Accuracy: 0.8564102564102564
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 3
# min_samples_split : 13
# Training Accuracy: 0.8581196581196581
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 13
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 3
# min_samples_split : 13
# Training Accuracy: 0.8581196581196581
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 3
# min_samples_split : 13
# Training Accuracy: 0.8547008547008547
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 3
# min_samples_split : 14
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 14
# Training Accuracy: 0.8905982905982905
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 3
# min_samples_split : 14
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 14
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 3
# min_samples_split : 14
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 3
# min_samples_split : 15
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 3
# min_samples_split : 15
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 15
# Training Accuracy: 0.852991452991453
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 15
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 15
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 16
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 3
# min_samples_split : 16
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 16
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 16
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 3
# min_samples_split : 16
# Training Accuracy: 0.8735042735042735
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 3
# min_samples_split : 17
# Training Accuracy: 0.8632478632478633
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 3
# min_samples_split : 17
# Training Accuracy: 0.8547008547008547
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 3
# min_samples_split : 17
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 17
# Training Accuracy: 0.8478632478632478
# Test Accuracy: 0.701195219123506
#
# min_samples_leaf : 3
# min_samples_split : 17
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 18
# Training Accuracy: 0.8717948717948718
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 18
# Training Accuracy: 0.864957264957265
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 3
# min_samples_split : 18
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 3
# min_samples_split : 18
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 3
# min_samples_split : 18
# Training Accuracy: 0.8598290598290599
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 19
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7649402390438247
#
# min_samples_leaf : 3
# min_samples_split : 19
# Training Accuracy: 0.8581196581196581
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 19
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 3
# min_samples_split : 19
# Training Accuracy: 0.8683760683760684
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 3
# min_samples_split : 19
# Training Accuracy: 0.8700854700854701
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 3
# min_samples_split : 20
# Training Accuracy: 0.8666666666666667
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 20
# Training Accuracy: 0.8615384615384616
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 3
# min_samples_split : 20
# Training Accuracy: 0.8564102564102564
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 3
# min_samples_split : 20
# Training Accuracy: 0.8735042735042735
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 3
# min_samples_split : 20
# Training Accuracy: 0.852991452991453
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 2
# Training Accuracy: 0.8017094017094017
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 2
# Training Accuracy: 0.8051282051282052
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 4
# min_samples_split : 2
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 2
# Training Accuracy: 0.8170940170940171
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 2
# Training Accuracy: 0.8341880341880342
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 3
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 3
# Training Accuracy: 0.8188034188034188
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 3
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 4
# min_samples_split : 3
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 4
# min_samples_split : 3
# Training Accuracy: 0.8256410256410256
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 4
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 4
# Training Accuracy: 0.8188034188034188
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 4
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 4
# Training Accuracy: 0.8017094017094017
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 4
# Training Accuracy: 0.8205128205128205
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 4
# min_samples_split : 5
# Training Accuracy: 0.8205128205128205
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 5
# Training Accuracy: 0.8256410256410256
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 5
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 5
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 5
# Training Accuracy: 0.8205128205128205
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 6
# Training Accuracy: 0.8256410256410256
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 6
# Training Accuracy: 0.8068376068376069
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 4
# min_samples_split : 6
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 6
# Training Accuracy: 0.8068376068376069
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 4
# min_samples_split : 6
# Training Accuracy: 0.8256410256410256
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 7
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 7
# Training Accuracy: 0.8324786324786325
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 7
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 4
# min_samples_split : 7
# Training Accuracy: 0.8017094017094017
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 7
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 8
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 4
# min_samples_split : 8
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 8
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 8
# Training Accuracy: 0.8205128205128205
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 4
# min_samples_split : 8
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 4
# min_samples_split : 9
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7609561752988048
#
# min_samples_leaf : 4
# min_samples_split : 9
# Training Accuracy: 0.8085470085470086
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 9
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 9
# Training Accuracy: 0.8256410256410256
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 9
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 10
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 4
# min_samples_split : 10
# Training Accuracy: 0.8085470085470086
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 10
# Training Accuracy: 0.8068376068376069
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 4
# min_samples_split : 10
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 10
# Training Accuracy: 0.8324786324786325
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 4
# min_samples_split : 11
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 4
# min_samples_split : 11
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 11
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 4
# min_samples_split : 11
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 11
# Training Accuracy: 0.8290598290598291
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 12
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 12
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 4
# min_samples_split : 12
# Training Accuracy: 0.8256410256410256
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 4
# min_samples_split : 12
# Training Accuracy: 0.8188034188034188
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 12
# Training Accuracy: 0.8290598290598291
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 13
# Training Accuracy: 0.8188034188034188
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 4
# min_samples_split : 13
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 4
# min_samples_split : 13
# Training Accuracy: 0.8239316239316239
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 4
# min_samples_split : 13
# Training Accuracy: 0.8205128205128205
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 13
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 14
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.701195219123506
#
# min_samples_leaf : 4
# min_samples_split : 14
# Training Accuracy: 0.8085470085470086
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 4
# min_samples_split : 14
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 14
# Training Accuracy: 0.8170940170940171
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 14
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 15
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 15
# Training Accuracy: 0.7777777777777778
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 4
# min_samples_split : 15
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 15
# Training Accuracy: 0.8273504273504273
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 15
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 16
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7051792828685259
#
# min_samples_leaf : 4
# min_samples_split : 16
# Training Accuracy: 0.8239316239316239
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 16
# Training Accuracy: 0.8170940170940171
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 4
# min_samples_split : 16
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 4
# min_samples_split : 16
# Training Accuracy: 0.8051282051282052
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 17
# Training Accuracy: 0.8188034188034188
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 17
# Training Accuracy: 0.8239316239316239
# Test Accuracy: 0.7569721115537849
#
# min_samples_leaf : 4
# min_samples_split : 17
# Training Accuracy: 0.8068376068376069
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 17
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 17
# Training Accuracy: 0.8085470085470086
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 18
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 4
# min_samples_split : 18
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 4
# min_samples_split : 18
# Training Accuracy: 0.8222222222222222
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 4
# min_samples_split : 18
# Training Accuracy: 0.811965811965812
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 18
# Training Accuracy: 0.8068376068376069
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 19
# Training Accuracy: 0.8136752136752137
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 4
# min_samples_split : 19
# Training Accuracy: 0.8205128205128205
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 4
# min_samples_split : 19
# Training Accuracy: 0.8239316239316239
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 4
# min_samples_split : 19
# Training Accuracy: 0.8341880341880342
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 4
# min_samples_split : 19
# Training Accuracy: 0.8290598290598291
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 20
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7529880478087649
#
# min_samples_leaf : 4
# min_samples_split : 20
# Training Accuracy: 0.8153846153846154
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 4
# min_samples_split : 20
# Training Accuracy: 0.8085470085470086
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 4
# min_samples_split : 20
# Training Accuracy: 0.8051282051282052
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 4
# min_samples_split : 20
# Training Accuracy: 0.8102564102564103
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 5
# min_samples_split : 2
# Training Accuracy: 0.7692307692307693
# Test Accuracy: 0.7051792828685259
#
# min_samples_leaf : 5
# min_samples_split : 2
# Training Accuracy: 0.7863247863247863
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 5
# min_samples_split : 2
# Training Accuracy: 0.7846153846153846
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 5
# min_samples_split : 2
# Training Accuracy: 0.7760683760683761
# Test Accuracy: 0.701195219123506
#
# min_samples_leaf : 5
# min_samples_split : 2
# Training Accuracy: 0.7692307692307693
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 5
# min_samples_split : 3
# Training Accuracy: 0.7606837606837606
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 5
# min_samples_split : 3
# Training Accuracy: 0.7726495726495727
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 5
# min_samples_split : 3
# Training Accuracy: 0.7863247863247863
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 5
# min_samples_split : 3
# Training Accuracy: 0.7829059829059829
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 5
# min_samples_split : 3
# Training Accuracy: 0.788034188034188
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 5
# min_samples_split : 4
# Training Accuracy: 0.7829059829059829
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 5
# min_samples_split : 4
# Training Accuracy: 0.7863247863247863
# Test Accuracy: 0.7450199203187251
#
# min_samples_leaf : 5
# min_samples_split : 4
# Training Accuracy: 0.7743589743589744
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 5
# min_samples_split : 4
# Training Accuracy: 0.7914529914529914
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 5
# min_samples_split : 4
# Training Accuracy: 0.7794871794871795
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 5
# min_samples_split : 5
# Training Accuracy: 0.7846153846153846
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 5
# min_samples_split : 5
# Training Accuracy: 0.7777777777777778
# Test Accuracy: 0.7051792828685259
#
# min_samples_leaf : 5
# min_samples_split : 5
# Training Accuracy: 0.7811965811965812
# Test Accuracy: 0.7410358565737052
#
# min_samples_leaf : 5
# min_samples_split : 5
# Training Accuracy: 0.7726495726495727
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 5
# min_samples_split : 5
# Training Accuracy: 0.7846153846153846
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 5
# min_samples_split : 6
# Training Accuracy: 0.7931623931623931
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 5
# min_samples_split : 6
# Training Accuracy: 0.764102564102564
# Test Accuracy: 0.6972111553784861
#
# min_samples_leaf : 5
# min_samples_split : 6
# Training Accuracy: 0.7777777777777778
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 5
# min_samples_split : 6
# Training Accuracy: 0.7982905982905983
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 5
# min_samples_split : 6
# Training Accuracy: 0.7692307692307693
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 5
# min_samples_split : 7
# Training Accuracy: 0.7692307692307693
# Test Accuracy: 0.7370517928286853
#
# min_samples_leaf : 5
# min_samples_split : 7
# Training Accuracy: 0.7777777777777778
# Test Accuracy: 0.7290836653386454
#
# min_samples_leaf : 5
# min_samples_split : 7
# Training Accuracy: 0.7692307692307693
# Test Accuracy: 0.7330677290836654
#
# min_samples_leaf : 5
# min_samples_split : 7
# Training Accuracy: 0.7623931623931623
# Test Accuracy: 0.749003984063745
#
# min_samples_leaf : 5
# min_samples_split : 7
# Training Accuracy: 0.7914529914529914
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 5
# min_samples_split : 8
# Training Accuracy: 0.7982905982905983
# Test Accuracy: 0.7131474103585658
#
# min_samples_leaf : 5
# min_samples_split : 8
# Training Accuracy: 0.7948717948717948
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 5
# min_samples_split : 8
# ...
# Training Accuracy: 0.7162393162393162
# Test Accuracy: 0.6812749003984063
#
# min_samples_leaf : 7
# min_samples_split : 12
# Training Accuracy: 0.7316239316239316
# Test Accuracy: 0.6972111553784861
#
# min_samples_leaf : 7
# min_samples_split : 13
# Training Accuracy: 0.7076923076923077
# Test Accuracy: 0.6852589641434262
#
# min_samples_leaf : 7
# min_samples_split : 13
# Training Accuracy: 0.7247863247863248
# Test Accuracy: 0.7250996015936255
#
# min_samples_leaf : 7
# min_samples_split : 13
# Training Accuracy: 0.7162393162393162
# Test Accuracy: 0.7171314741035857
#
# min_samples_leaf : 7
# min_samples_split : 13
# Training Accuracy: 0.7042735042735043
# Test Accuracy: 0.6772908366533864
#
# min_samples_leaf : 7
# min_samples_split : 13
# Training Accuracy: 0.7230769230769231
# Test Accuracy: 0.7051792828685259
#
# min_samples_leaf : 7
# min_samples_split : 14
# Training Accuracy: 0.6820512820512821
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 7
# min_samples_split : 14
# Training Accuracy: 0.7128205128205128
# Test Accuracy: 0.6653386454183267
#
# min_samples_leaf : 7
# min_samples_split : 14
# Training Accuracy: 0.7418803418803419
# Test Accuracy: 0.6852589641434262
#
# min_samples_leaf : 7
# min_samples_split : 14
# Training Accuracy: 0.7418803418803419
# Test Accuracy: 0.7211155378486056
#
# min_samples_leaf : 7
# min_samples_split : 14
# Training Accuracy: 0.6683760683760683
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 7
# min_samples_split : 15
# Training Accuracy: 0.7264957264957265
# Test Accuracy: 0.701195219123506
#
# min_samples_leaf : 7
# min_samples_split : 15
# Training Accuracy: 0.652991452991453
# Test Accuracy: 0.5936254980079682
#
# min_samples_leaf : 7
# min_samples_split : 15
# Training Accuracy: 0.67008547008547
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 7
# min_samples_split : 15
# Training Accuracy: 0.7435897435897436
# Test Accuracy: 0.6733067729083665
#
# min_samples_leaf : 7
# min_samples_split : 15
# Training Accuracy: 0.6735042735042736
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 7
# min_samples_split : 16
# Training Accuracy: 0.6615384615384615
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 7
# min_samples_split : 16
# Training Accuracy: 0.7196581196581197
# Test Accuracy: 0.6693227091633466
#
# min_samples_leaf : 7
# min_samples_split : 16
# Training Accuracy: 0.7384615384615385
# Test Accuracy: 0.6772908366533864
#
# min_samples_leaf : 7
# min_samples_split : 16
# Training Accuracy: 0.7401709401709402
# Test Accuracy: 0.6772908366533864
#
# min_samples_leaf : 7
# min_samples_split : 16
# Training Accuracy: 0.7350427350427351
# Test Accuracy: 0.6892430278884463
#
# min_samples_leaf : 7
# min_samples_split : 17
# Training Accuracy: 0.6547008547008547
# Test Accuracy: 0.5896414342629482
#
# min_samples_leaf : 7
# min_samples_split : 17
# Training Accuracy: 0.6683760683760683
# Test Accuracy: 0.5896414342629482
#
# min_samples_leaf : 7
# min_samples_split : 17
# Training Accuracy: 0.6974358974358974
# Test Accuracy: 0.7091633466135459
#
# min_samples_leaf : 7
# min_samples_split : 17
# Training Accuracy: 0.7401709401709402
# Test Accuracy: 0.6972111553784861
#
# min_samples_leaf : 7
# min_samples_split : 17
# Training Accuracy: 0.7162393162393162
# Test Accuracy: 0.6852589641434262
#
# min_samples_leaf : 7
# min_samples_split : 18
# Training Accuracy: 0.7042735042735043
# Test Accuracy: 0.701195219123506
#
# min_samples_leaf : 7
# min_samples_split : 18
# Training Accuracy: 0.7367521367521368
# Test Accuracy: 0.6892430278884463
#
# min_samples_leaf : 7
# min_samples_split : 18
# Training Accuracy: 0.7316239316239316
# Test Accuracy: 0.6733067729083665
#
# min_samples_leaf : 7
# min_samples_split : 18
# Training Accuracy: 0.7128205128205128
# Test Accuracy: 0.6892430278884463
#
# min_samples_leaf : 7
# min_samples_split : 18
# Training Accuracy: 0.7282051282051282
# Test Accuracy: 0.6812749003984063
#
# min_samples_leaf : 7
# min_samples_split : 19
# Training Accuracy: 0.717948717948718
# Test Accuracy: 0.6613545816733067
#
# min_samples_leaf : 7
# min_samples_split : 19
# Training Accuracy: 0.6632478632478632
# Test Accuracy: 0.5737051792828686
#
# min_samples_leaf : 7
# min_samples_split : 19
# Training Accuracy: 0.7230769230769231
# Test Accuracy: 0.6812749003984063
#
# min_samples_leaf : 7
# min_samples_split : 19
# Training Accuracy: 0.7162393162393162
# Test Accuracy: 0.6733067729083665
#
# min_samples_leaf : 7
# min_samples_split : 19
# Training Accuracy: 0.7333333333333333
# Test Accuracy: 0.649402390438247
#
# min_samples_leaf : 7
# min_samples_split : 20
# Training Accuracy: 0.7128205128205128
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 7
# min_samples_split : 20
# Training Accuracy: 0.7076923076923077
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 7
# min_samples_split : 20
# Training Accuracy: 0.7042735042735043
# Test Accuracy: 0.6812749003984063
#
# min_samples_leaf : 7
# min_samples_split : 20
# Training Accuracy: 0.6820512820512821
# Test Accuracy: 0.5896414342629482
#
# min_samples_leaf : 7
# min_samples_split : 20
# Training Accuracy: 0.652991452991453
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 2
# Training Accuracy: 0.6170940170940171
# Test Accuracy: 0.5338645418326693
#
# min_samples_leaf : 8
# min_samples_split : 2
# Training Accuracy: 0.705982905982906
# Test Accuracy: 0.6892430278884463
#
# min_samples_leaf : 8
# min_samples_split : 2
# Training Accuracy: 0.705982905982906
# Test Accuracy: 0.6852589641434262
#
# min_samples_leaf : 8
# min_samples_split : 2
# Training Accuracy: 0.6376068376068376
# Test Accuracy: 0.5418326693227091
#
# min_samples_leaf : 8
# min_samples_split : 2
# Training Accuracy: 0.6717948717948717
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 3
# Training Accuracy: 0.6581196581196581
# Test Accuracy: 0.5776892430278885
#
# min_samples_leaf : 8
# min_samples_split : 3
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5418326693227091
#
# min_samples_leaf : 8
# min_samples_split : 3
# Training Accuracy: 0.6256410256410256
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 3
# Training Accuracy: 0.629059829059829
# Test Accuracy: 0.5338645418326693
#
# min_samples_leaf : 8
# min_samples_split : 3
# Training Accuracy: 0.6478632478632479
# Test Accuracy: 0.5737051792828686
#
# min_samples_leaf : 8
# min_samples_split : 4
# Training Accuracy: 0.6341880341880342
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 4
# Training Accuracy: 0.6153846153846154
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 4
# Training Accuracy: 0.6273504273504273
# Test Accuracy: 0.5298804780876494
#
# min_samples_leaf : 8
# min_samples_split : 4
# Training Accuracy: 0.6478632478632479
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 4
# Training Accuracy: 0.6427350427350428
# Test Accuracy: 0.5896414342629482
#
# min_samples_leaf : 8
# min_samples_split : 5
# Training Accuracy: 0.6495726495726496
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 5
# Training Accuracy: 0.7162393162393162
# Test Accuracy: 0.6533864541832669
#
# min_samples_leaf : 8
# min_samples_split : 5
# Training Accuracy: 0.6341880341880342
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 5
# Training Accuracy: 0.6393162393162393
# Test Accuracy: 0.5776892430278885
#
# min_samples_leaf : 8
# min_samples_split : 5
# Training Accuracy: 0.6410256410256411
# Test Accuracy: 0.5378486055776892
#
# min_samples_leaf : 8
# min_samples_split : 6
# Training Accuracy: 0.6581196581196581
# Test Accuracy: 0.5776892430278885
#
# min_samples_leaf : 8
# min_samples_split : 6
# Training Accuracy: 0.6461538461538462
# Test Accuracy: 0.5936254980079682
#
# min_samples_leaf : 8
# min_samples_split : 6
# Training Accuracy: 0.6273504273504273
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 6
# Training Accuracy: 0.6051282051282051
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 6
# Training Accuracy: 0.7042735042735043
# Test Accuracy: 0.701195219123506
#
# min_samples_leaf : 8
# min_samples_split : 7
# Training Accuracy: 0.6017094017094017
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 7
# Training Accuracy: 0.717948717948718
# Test Accuracy: 0.6812749003984063
#
# min_samples_leaf : 8
# min_samples_split : 7
# Training Accuracy: 0.5897435897435898
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 7
# Training Accuracy: 0.6512820512820513
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 7
# Training Accuracy: 0.7042735042735043
# Test Accuracy: 0.6812749003984063
#
# min_samples_leaf : 8
# min_samples_split : 8
# Training Accuracy: 0.6410256410256411
# Test Accuracy: 0.5697211155378487
#
# min_samples_leaf : 8
# min_samples_split : 8
# Training Accuracy: 0.6410256410256411
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 8
# Training Accuracy: 0.6581196581196581
# Test Accuracy: 0.5936254980079682
#
# min_samples_leaf : 8
# min_samples_split : 8
# Training Accuracy: 0.6341880341880342
# Test Accuracy: 0.5936254980079682
#
# min_samples_leaf : 8
# min_samples_split : 8
# Training Accuracy: 0.6666666666666666
# Test Accuracy: 0.5697211155378487
#
# min_samples_leaf : 8
# min_samples_split : 9
# Training Accuracy: 0.7008547008547008
# Test Accuracy: 0.649402390438247
#
# min_samples_leaf : 8
# min_samples_split : 9
# Training Accuracy: 0.7111111111111111
# Test Accuracy: 0.6772908366533864
#
# min_samples_leaf : 8
# min_samples_split : 9
# Training Accuracy: 0.6153846153846154
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 9
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 9
# Training Accuracy: 0.6461538461538462
# Test Accuracy: 0.5776892430278885
#
# min_samples_leaf : 8
# min_samples_split : 10
# Training Accuracy: 0.5897435897435898
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 10
# Training Accuracy: 0.6512820512820513
# Test Accuracy: 0.5737051792828686
#
# min_samples_leaf : 8
# min_samples_split : 10
# Training Accuracy: 0.6461538461538462
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 10
# Training Accuracy: 0.6273504273504273
# Test Accuracy: 0.545816733067729
#
# min_samples_leaf : 8
# min_samples_split : 10
# Training Accuracy: 0.629059829059829
# Test Accuracy: 0.549800796812749
#
# min_samples_leaf : 8
# min_samples_split : 11
# Training Accuracy: 0.6461538461538462
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 11
# Training Accuracy: 0.6170940170940171
# Test Accuracy: 0.5418326693227091
#
# min_samples_leaf : 8
# min_samples_split : 11
# Training Accuracy: 0.6188034188034188
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 11
# Training Accuracy: 0.6427350427350428
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 11
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 12
# Training Accuracy: 0.6444444444444445
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 12
# Training Accuracy: 0.6393162393162393
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 12
# Training Accuracy: 0.6461538461538462
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 12
# Training Accuracy: 0.6991452991452991
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 8
# min_samples_split : 12
# Training Accuracy: 0.6478632478632479
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 13
# Training Accuracy: 0.7128205128205128
# Test Accuracy: 0.6892430278884463
#
# min_samples_leaf : 8
# min_samples_split : 13
# Training Accuracy: 0.7025641025641025
# Test Accuracy: 0.6733067729083665
#
# min_samples_leaf : 8
# min_samples_split : 13
# Training Accuracy: 0.7042735042735043
# Test Accuracy: 0.6892430278884463
#
# min_samples_leaf : 8
# min_samples_split : 13
# Training Accuracy: 0.705982905982906
# Test Accuracy: 0.6733067729083665
#
# min_samples_leaf : 8
# min_samples_split : 13
# Training Accuracy: 0.7128205128205128
# Test Accuracy: 0.7051792828685259
#
# min_samples_leaf : 8
# min_samples_split : 14
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 14
# Training Accuracy: 0.6427350427350428
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 14
# Training Accuracy: 0.6307692307692307
# Test Accuracy: 0.5856573705179283
#
# min_samples_leaf : 8
# min_samples_split : 14
# Training Accuracy: 0.7111111111111111
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 8
# min_samples_split : 14
# Training Accuracy: 0.6239316239316239
# Test Accuracy: 0.5338645418326693
#
# min_samples_leaf : 8
# min_samples_split : 15
# Training Accuracy: 0.6512820512820513
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 15
# Training Accuracy: 0.7196581196581197
# Test Accuracy: 0.6852589641434262
#
# min_samples_leaf : 8
# min_samples_split : 15
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5697211155378487
#
# min_samples_leaf : 8
# min_samples_split : 15
# Training Accuracy: 0.6427350427350428
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 15
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5856573705179283
#
# min_samples_leaf : 8
# min_samples_split : 16
# Training Accuracy: 0.6991452991452991
# Test Accuracy: 0.6852589641434262
#
# min_samples_leaf : 8
# min_samples_split : 16
# Training Accuracy: 0.629059829059829
# Test Accuracy: 0.5936254980079682
#
# min_samples_leaf : 8
# min_samples_split : 16
# Training Accuracy: 0.6649572649572649
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 16
# Training Accuracy: 0.717948717948718
# Test Accuracy: 0.6733067729083665
#
# min_samples_leaf : 8
# min_samples_split : 16
# Training Accuracy: 0.6615384615384615
# Test Accuracy: 0.5697211155378487
#
# min_samples_leaf : 8
# min_samples_split : 17
# Training Accuracy: 0.6512820512820513
# Test Accuracy: 0.5617529880478087
#
# min_samples_leaf : 8
# min_samples_split : 17
# Training Accuracy: 0.6239316239316239
# Test Accuracy: 0.5856573705179283
#
# min_samples_leaf : 8
# min_samples_split : 17
# Training Accuracy: 0.6256410256410256
# Test Accuracy: 0.5697211155378487
#
# min_samples_leaf : 8
# min_samples_split : 17
# Training Accuracy: 0.6307692307692307
# Test Accuracy: 0.5776892430278885
#
# min_samples_leaf : 8
# min_samples_split : 17
# Training Accuracy: 0.6170940170940171
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 18
# Training Accuracy: 0.6239316239316239
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 18
# Training Accuracy: 0.6581196581196581
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 18
# Training Accuracy: 0.6358974358974359
# Test Accuracy: 0.5816733067729084
#
# min_samples_leaf : 8
# min_samples_split : 18
# Training Accuracy: 0.717948717948718
# Test Accuracy: 0.6932270916334662
#
# min_samples_leaf : 8
# min_samples_split : 18
# Training Accuracy: 0.6427350427350428
# Test Accuracy: 0.5737051792828686
#
# min_samples_leaf : 8
# min_samples_split : 19
# Training Accuracy: 0.6324786324786325
# Test Accuracy: 0.5737051792828686
#
# min_samples_leaf : 8
# min_samples_split : 19
# Training Accuracy: 0.6410256410256411
# Test Accuracy: 0.5577689243027888
#
# min_samples_leaf : 8
# min_samples_split : 19
# Training Accuracy: 0.7076923076923077
# Test Accuracy: 0.6573705179282868
#
# min_samples_leaf : 8
# min_samples_split : 19
# Training Accuracy: 0.694017094017094
# Test Accuracy: 0.6573705179282868
#
# min_samples_leaf : 8
# min_samples_split : 19
# Training Accuracy: 0.6393162393162393
# Test Accuracy: 0.5657370517928287
#
# min_samples_leaf : 8
# min_samples_split : 20
# Training Accuracy: 0.6444444444444445
# Test Accuracy: 0.5856573705179283
#
# min_samples_leaf : 8
# min_samples_split : 20
# Training Accuracy: 0.6341880341880342
# Test Accuracy: 0.5737051792828686
#
# min_samples_leaf : 8
# min_samples_split : 20
# Training Accuracy: 0.6495726495726496
# Test Accuracy: 0.5537848605577689
#
# min_samples_leaf : 8
# min_samples_split : 20
# Training Accuracy: 0.7008547008547008
# Test Accuracy: 0.6772908366533864
#
# min_samples_leaf : 8
# min_samples_split : 20
# Training Accuracy: 0.6170940170940171
# Test Accuracy: 0.549800796812749
#
#
# Training Accuracy: 0.9418803418803419
# Akurasi plg bagus : 0.7888446215139442

# %%
best_model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 48,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
"""
0.2 351 k
Best hyperparameters: {'min_samples_leaf': 1, 'min_samples_split': 13, 'n_estimators': 414} dan max depth none
Train Accuracy: 0.9431137724550899
Test Accuracy: 0.8511904761904762

0.2 101 k
Best hyperparameters: {'min_samples_leaf': 1, 'min_samples_split': 20, 'n_estimators': 225} dan max depth none
Train Accuracy: 0.8473053892215568
Test Accuracy: 0.8392857142857143

0.3 split 2000 k
Training Accuracy: 0.9641025641025641
Akurasi plg bagus : 0.8446215139442231
{'bootstrap': True,
 'ccp_alpha': 0.0,
 'class_weight': None,
 'criterion': 'gini',
 'max_depth': None,
 'max_features': 'sqrt',
 'max_leaf_nodes': None,
 'max_samples': None,
 'min_impurity_decrease': 0.0,
 'min_samples_leaf': 1,
 'min_samples_split': 9,
 'min_weight_fraction_leaf': 0.0,
 'monotonic_cst': None,
 'n_estimators': 48,
 'n_jobs': None,
 'oob_score': False,
 'random_state': None,
 'verbose': 0,
 'warm_start': False}

0.3 split
Training Accuracy: 0.9623931623931624
Akurasi plg bagus : 0.8366533864541833
{'bootstrap': True,
 'ccp_alpha': 0.0,
 'class_weight': None,
 'criterion': 'gini',
 'max_depth': None,
 'max_features': 'sqrt',
 'max_leaf_nodes': None,
 'max_samples': None,
 'min_impurity_decrease': 0.0,
 'min_samples_leaf': 1,
 'min_samples_split': 9,
 'min_weight_fraction_leaf': 0.0,
 'monotonic_cst': None,
 'n_estimators': 48,
 'n_jobs': None,
 'oob_score': False,
 'random_state': None,
 'verbose': 0,
 'warm_start': False}

train : 0.9145299145299145
Akurasi plg bagus : 0.8326693227091634
{'bootstrap': True,
 'ccp_alpha': 0.0,
 'class_weight': None,
 'criterion': 'gini',
 'max_depth': 50,
 'max_features': 'sqrt',
 'max_leaf_nodes': None,
 'max_samples': None,
 'min_impurity_decrease': 0.0,
 'min_samples_leaf': 1,
 'min_samples_split': 12,
 'min_weight_fraction_leaf': 0.0,
 'monotonic_cst': None,
 'n_estimators': 48,
 'n_jobs': None,
 'oob_score': False,
 'random_state': None,
 'verbose': 0,
 'warm_start': False}

Training Accuracy: 0.8786324786324786
Akurasi plg bagus : 0.8286852589641435
{'bootstrap': True,
 'ccp_alpha': 0.0,
 'class_weight': None,
 'criterion': 'gini',
 'max_depth': 40,
 'max_features': 'sqrt',
 'max_leaf_nodes': None,
 'max_samples': None,
 'min_impurity_decrease': 0.0,
 'min_samples_leaf': 1,
 'min_samples_split': 9,
 'min_weight_fraction_leaf': 0.0,
 'monotonic_cst': None,
 'n_estimators': 48,
 'n_jobs': None,
 'oob_score': False,
 'random_state': None,
 'verbose': 0,
 'warm_start': False}

30
Akurasi plg bagus : 0.8167330677290837

train : 0.9145299145299145
Akurasi plg bagus : 0.8326693227091634
{'bootstrap': True,
 'ccp_alpha': 0.0,
 'class_weight': None,
 'criterion': 'gini',
 'max_depth': 50,
 'max_features': 'sqrt',
 'max_leaf_nodes': None,
 'max_samples': None,
 'min_impurity_decrease': 0.0,
 'min_samples_leaf': 1,
 'min_samples_split': 12,
 'min_weight_fraction_leaf': 0.0,
 'monotonic_cst': None,
 'n_estimators': 48,
 'n_jobs': None,
 'oob_score': False,
 'random_state': None,
 'verbose': 0,
 'warm_start': False}

max  depth 40
Akurasi plg bagus : 0.8214285714285714

max depth :35
Akurasi plg bagus : 0.8273809523809523

max depth :35
Akurasi plg bagus : 0.8214285714285714
"""
# Out:
#   File "<ipython-input-187-969763094>", line 1
#     """
#     ^
# SyntaxError: incomplete input

# %%
best_model = None
best_acc = -1
for i in range(25):
  model = best_rf
  model.fit(X_train, y_train)

  y_pred = model.predict(X_test)
  accuracy = accuracy_score(y_test, y_pred)

  print(i, end=', ')
  print("Train Accuracy:", np.mean(y_train == best_rf.predict(X_train)), end=', ')
  print("Test Accuracy:", accuracy)

  if accuracy > best_acc:
    best_model = model
    best_acc = accuracy
print(f"Best acc is : {best_acc}")
print('Best hyperparameters:',  best_model.get_params())
# Out:
# 0, Train Accuracy: 0.8488023952095808, Test Accuracy: 0.7202380952380952
# 1, Train Accuracy: 0.8502994011976048, Test Accuracy: 0.7083333333333334
# 2, Train Accuracy: 0.8458083832335329, Test Accuracy: 0.7202380952380952
# 3, Train Accuracy: 0.8383233532934131, Test Accuracy: 0.7380952380952381
# 4, Train Accuracy: 0.842814371257485, Test Accuracy: 0.7380952380952381
# 5, Train Accuracy: 0.8413173652694611, Test Accuracy: 0.7440476190476191
# 6, Train Accuracy: 0.842814371257485, Test Accuracy: 0.7261904761904762
# 7, Train Accuracy: 0.8502994011976048, Test Accuracy: 0.7083333333333334
# 8, Train Accuracy: 0.8502994011976048, Test Accuracy: 0.7440476190476191
# 9, Train Accuracy: 0.8488023952095808, Test Accuracy: 0.7142857142857143
# 10, Train Accuracy: 0.8502994011976048, Test Accuracy: 0.7142857142857143
# 11, Train Accuracy: 0.8517964071856288, Test Accuracy: 0.7440476190476191
# 12, Train Accuracy: 0.8458083832335329, Test Accuracy: 0.7321428571428571
# 13, Train Accuracy: 0.8458083832335329, Test Accuracy: 0.7619047619047619
# 14, Train Accuracy: 0.844311377245509, Test Accuracy: 0.7142857142857143
# 15, Train Accuracy: 0.842814371257485, Test Accuracy: 0.7142857142857143
# 16, Train Accuracy: 0.8607784431137725, Test Accuracy: 0.7738095238095238
# 17, Train Accuracy: 0.8488023952095808, Test Accuracy: 0.7083333333333334
# 18, Train Accuracy: 0.842814371257485, Test Accuracy: 0.7321428571428571
# 19, Train Accuracy: 0.8458083832335329, Test Accuracy: 0.7261904761904762
# 20, Train Accuracy: 0.8458083832335329, Test Accuracy: 0.7202380952380952
# 21, Train Accuracy: 0.842814371257485, Test Accuracy: 0.7380952380952381
# 22, Train Accuracy: 0.8577844311377245, Test Accuracy: 0.7261904761904762
# 23, Train Accuracy: 0.8458083832335329, Test Accuracy: 0.7380952380952381
# 24, Train Accuracy: 0.8368263473053892, Test Accuracy: 0.7440476190476191
# Best acc is : 0.7738095238095238
# Best hyperparameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 25, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %%
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(i, end=', ')
print("Train Accuracy:", np.mean(y_train == best_rf.predict(X_train)), end=', ')
print("Test Accuracy:", accuracy)
# Out:
# 24, Train Accuracy: 0.8368263473053892, Test Accuracy: 0.7440476190476191

# %%
y_pred = best_rf.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("Train Accuracy:", np.mean(y_train == best_rf.predict(X_train)))
print("Test Accuracy:", accuracy)
# Out:
# Train Accuracy: 0.8622754491017964
# Test Accuracy: 0.7142857142857143

# %%
# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# ## **Neural Network**

# %%
# transform = transforms.Compose([
#     transforms.ToTensor()  # Convert to PyTorch tensor
# ])

tensor_x = torch.from_numpy(X_train.astype('float32').todense())
tensor_y = torch.Tensor(y_train)

tensor_x_test = torch.Tensor(X_test.astype('float32').todense()) # transform to torch tensor
tensor_y_test = torch.Tensor(y_test.to_numpy())

train_dataset = TensorDataset(tensor_x,tensor_y)
test_dataset = TensorDataset(tensor_x_test,tensor_y_test)

loader_train = DataLoader(train_dataset, batch_size=10, shuffle=False)
loader_test = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
y_train
# Out:
# 346    0
# 462    0
# 691    1
# 302    1
# 763    0
#       ..
# 71     0
# 106    1
# 270    1
# 435    0
# 102    0
# Name: sentiment, Length: 668, dtype: int64

# %%
lr = 10**random.uniform(2,-6)

# %%
class Net(nn.Module):
    def __init__(self, input_dim, classes):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, 500)
        self.fc2 = nn.Linear(500, classes)
        # self.fc3 = nn.Linear(100, 30)
        # self.fc4 = nn.Linear(30, 30)
        # self.fc5 = nn.Linear(30, classes)
        # self.fc5 = nn.Linear(84, classes)

    def forward(self, x):
        x = x.float()
        # x = F.sigmoid(self.fc1(x))
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        # x = F.relu(self.fc3(x))
        # x = F.relu(self.fc4(x))
        # x = self.fc5(x)

        # x = self.fc1(x)


        # x = F.relu(self.fc2(x))
        # x = self.fc(x)
        return x

# %%
criterion = nn.CrossEntropyLoss()
for j in range(1):
  net = Net(937, 2)

  # print(f"lr : {lr}")
  optimizer = optim.Adam(net.parameters(), lr=1.584618639910894e-05) # 1.584618639910894e-05
  for epoch in range(50):  # loop over the dataset multiple times

      running_loss = 0.0
      for i, data in enumerate(loader_train, 0):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          labels = labels.long()
          # print(inputs.dtype)
          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 64 == 500:    # print every 2000 mini-batches
              print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
              running_loss = 0.0

      print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
  correct = 0
  total = 0
  # since we're not training, we don't need to calculate the gradients for our outputs
  with torch.no_grad():
      for data in loader_test:
          images, labels = data
          # calculate outputs by running images through the network
          outputs = net(images)
          # the class with the highest energy is what we choose as prediction
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

  print(f'Accuracy of the network: {100 * correct // total} %')

  print('Finished Training')
# Out:
# [1,    67] loss: 0.023
# [2,    67] loss: 0.023
# [3,    67] loss: 0.023
# [4,    67] loss: 0.023
# [5,    67] loss: 0.023
# [6,    67] loss: 0.023
# [7,    67] loss: 0.023
# [8,    67] loss: 0.023
# [9,    67] loss: 0.023
# [10,    67] loss: 0.023
# [11,    67] loss: 0.023
# [12,    67] loss: 0.023
# [13,    67] loss: 0.023
# [14,    67] loss: 0.023
# [15,    67] loss: 0.023
# [16,    67] loss: 0.022
# [17,    67] loss: 0.022
# [18,    67] loss: 0.022
# [19,    67] loss: 0.022
# [20,    67] loss: 0.022
# [21,    67] loss: 0.022
# [22,    67] loss: 0.022
# [23,    67] loss: 0.022
# [24,    67] loss: 0.022
# [25,    67] loss: 0.022
# [26,    67] loss: 0.021
# [27,    67] loss: 0.021
# [28,    67] loss: 0.021
# [29,    67] loss: 0.021
# [30,    67] loss: 0.021
# [31,    67] loss: 0.021
# [32,    67] loss: 0.021
# [33,    67] loss: 0.021
# [34,    67] loss: 0.020
# [35,    67] loss: 0.020
# [36,    67] loss: 0.020
# [37,    67] loss: 0.020
# [38,    67] loss: 0.020
# [39,    67] loss: 0.019
# [40,    67] loss: 0.019
# [41,    67] loss: 0.019
# [42,    67] loss: 0.019
# [43,    67] loss: 0.019
# [44,    67] loss: 0.019
# [45,    67] loss: 0.018
# [46,    67] loss: 0.018
# [47,    67] loss: 0.018
# [48,    67] loss: 0.018
# [49,    67] loss: 0.018
# [50,    67] loss: 0.017
# Accuracy of the network: 73 %
# Finished Training

# %%
y_pred = np.array([])
with torch.no_grad():
      for data in loader_test:

          images, labels = data
          # calculate outputs by running images through the network
          outputs = net(images)
          # the class with the highest energy is what we choose as prediction
          _, predicted = torch.max(outputs.data, 1)

          y_pred = np.concatenate((y_pred, predicted.numpy()))

# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# ## **Neural Network dengan perbaikan akurasi**

# %% [markdown]
# ## **Course search**

# %%
for j in range(100):
  net = Net(351, 2)
  lr = 10**random.uniform(2,-6)
  reg = 10**random.uniform(-5,5)

  optimizer = optim.Adam(net.parameters(), lr=lr,weight_decay=reg) # 1.584618639910894e-05
  for epoch in range(5):  # loop over the dataset multiple times

      running_loss = 0.0
      for i, data in enumerate(loader_train, 0):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          labels = labels.long()
          # print(inputs.dtype)
          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 64 == 500:    # print every 2000 mini-batches
              print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
              running_loss = 0.0
  print(f"lr : {lr}, reg : {reg}", end=', ')
      # print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
  # correct = 0
  # total = 0
  # with torch.no_grad():
  #     for data in loader_train:
  #         images, labels = data
  #         # calculate outputs by running images through the network
  #         outputs = net(images)
  #         # the class with the highest energy is what we choose as prediction
  #         _, predicted = torch.max(outputs.data, 1)
  #         total += labels.size(0)
  #         correct += (predicted == labels).sum().item()
  # print(f'Accuracy training: {100 * correct // total} %')
  correct = 0
  total = 0
  # since we're not training, we don't need to calculate the gradients for our outputs
  with torch.no_grad():
      for data in loader_test:
          images, labels = data
          # calculate outputs by running images through the network
          outputs = net(images)
          # the class with the highest energy is what we choose as prediction
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()



  print(f'Accuracy testing: {100 * correct // total} %')

  # print('Finished Training')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-256-2398314914> in <cell line: 0>()
#      17
#      18           # forward + backward + optimize
# ---> 19           outputs = net(inputs)
#      20           loss = criterion(outputs, labels)
#      21           loss.backward()
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# <ipython-input-255-2306272889> in forward(self, x)
#      16         x = x.float()
#      17         # x = F.sigmoid(self.fc1(x))
# ---> 18         x = F.relu((self.fc1(x)))
#      19         x = self.fc2(x)
#      20         # x = F.relu(self.fc3(x))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (10x937 and 351x500)

# %% [markdown]
# ## **Finer search**

# %%
best_model = None
best_acc = -1
for j in range(100):
  net = Net(351, 2)
  lr = 10**random.uniform(-4,-2)
  reg = 10**random.uniform(-5,-4)

  optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=1e-2) # 1.584618639910894e-05
  for epoch in range(50):  # loop over the dataset multiple times

      running_loss = 0.0
      for i, data in enumerate(loader_train, 0):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          labels = labels.long()
          # print(inputs.dtype)
          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 64 == 500:    # print every 2000 mini-batches
              print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
              running_loss = 0.0
      correct = 0
      total = 0
      # since we're not training, we don't need to calculate the gradients for our outputs
      with torch.no_grad():
          for data in loader_test:
              images, labels = data
              # calculate outputs by running images through the network
              outputs = net(images)
              # the class with the highest energy is what we choose as prediction
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              correct += (predicted == labels).sum().item()
      print(f'Accuracy testing: {100 * correct // total} %')
      acc = 100 * correct // total
      if acc > best_acc:
        best_model = net
        best_acc = acc
  print(f"lr : {lr}, reg : {reg}", end=', ')

      # print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
  # correct = 0
  # total = 0
  # with torch.no_grad():
  #     for data in loader_train:
  #         images, labels = data
  #         # calculate outputs by running images through the network
  #         outputs = net(images)
  #         # the class with the highest energy is what we choose as prediction
  #         _, predicted = torch.max(outputs.data, 1)
  #         total += labels.size(0)
  #         correct += (predicted == labels).sum().item()
  # print(f'Accuracy training: {100 * correct // total} %')






  print('Finished Training')
  print(f"Best acc : {best_acc}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0010424755150341325, reg : 1.0065452881806632e-05, Finished Training
# Best acc : 89
# Accuracy testing: 77 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.001068731153357516, reg : 2.3916485082975818e-05, Finished Training
# Best acc : 89
# Accuracy testing: 57 %
# Accuracy testing: 58 %
# Accuracy testing: 61 %
# Accuracy testing: 67 %
# Accuracy testing: 73 %
# Accuracy testing: 77 %
# Accuracy testing: 78 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0002037389963642411, reg : 9.264334765470324e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 78 %
# Accuracy testing: 79 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.003805406239519604, reg : 1.0157170986811301e-05, Finished Training
# Best acc : 89
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0013019684408158278, reg : 6.153396909079575e-05, Finished Training
# Best acc : 89
# Accuracy testing: 66 %
# Accuracy testing: 75 %
# Accuracy testing: 66 %
# Accuracy testing: 67 %
# Accuracy testing: 71 %
# Accuracy testing: 71 %
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 78 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00015515088669054697, reg : 1.765447561027994e-05, Finished Training
# Best acc : 89
# Accuracy testing: 61 %
# Accuracy testing: 84 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0007046055840475563, reg : 7.583048066110811e-05, Finished Training
# Best acc : 89
# Accuracy testing: 55 %
# Accuracy testing: 55 %
# Accuracy testing: 57 %
# Accuracy testing: 60 %
# Accuracy testing: 64 %
# Accuracy testing: 69 %
# Accuracy testing: 74 %
# Accuracy testing: 76 %
# Accuracy testing: 78 %
# Accuracy testing: 84 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00015564551652465624, reg : 1.5206586907550076e-05, Finished Training
# Best acc : 89
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0014177187752731101, reg : 1.003521143606625e-05, Finished Training
# Best acc : 89
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0057838075003984815, reg : 4.39095052993436e-05, Finished Training
# Best acc : 89
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.006200938976483596, reg : 1.532808605330903e-05, Finished Training
# Best acc : 89
# Accuracy testing: 57 %
# Accuracy testing: 58 %
# Accuracy testing: 64 %
# Accuracy testing: 67 %
# Accuracy testing: 75 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00023749476890604977, reg : 7.963564504965148e-05, Finished Training
# Best acc : 89
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 77 %
# Accuracy testing: 79 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# lr : 0.008629958278393145, reg : 2.4955052812398075e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0008469244188392435, reg : 1.070575417658904e-05, Finished Training
# Best acc : 89
# Accuracy testing: 83 %
# Accuracy testing: 82 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0009453886079410024, reg : 1.0137372488443845e-05, Finished Training
# Best acc : 89
# Accuracy testing: 71 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0007874272040358342, reg : 6.612583567417935e-05, Finished Training
# Best acc : 89
# Accuracy testing: 55 %
# Accuracy testing: 55 %
# Accuracy testing: 60 %
# Accuracy testing: 68 %
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00024209145705369575, reg : 1.1061959018348766e-05, Finished Training
# Best acc : 89
# Accuracy testing: 54 %
# Accuracy testing: 57 %
# Accuracy testing: 62 %
# Accuracy testing: 63 %
# Accuracy testing: 69 %
# Accuracy testing: 75 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00021449853611822913, reg : 3.2721466383653425e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0037271412027652198, reg : 4.3360621910943796e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 78 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.003322241826891813, reg : 2.3554724425595816e-05, Finished Training
# Best acc : 89
# Accuracy testing: 59 %
# Accuracy testing: 64 %
# Accuracy testing: 70 %
# Accuracy testing: 76 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00028805548998062433, reg : 5.7033971588705304e-05, Finished Training
# Best acc : 89
# Accuracy testing: 60 %
# Accuracy testing: 66 %
# Accuracy testing: 75 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00035874172045424654, reg : 1.0554363296104306e-05, Finished Training
# Best acc : 89
# Accuracy testing: 79 %
# Accuracy testing: 83 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0018851765456051172, reg : 3.261783912528759e-05, Finished Training
# Best acc : 89
# Accuracy testing: 70 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0007360619449400738, reg : 8.350260789072471e-05, Finished Training
# Best acc : 89
# Accuracy testing: 76 %
# Accuracy testing: 76 %
# Accuracy testing: 79 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# lr : 0.006482482300332787, reg : 5.952324678807354e-05, Finished Training
# Best acc : 89
# Accuracy testing: 80 %
# Accuracy testing: 83 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0017964488770994165, reg : 4.9752403431065926e-05, Finished Training
# Best acc : 89
# Accuracy testing: 79 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0020492845493733603, reg : 4.8077803161114656e-05, Finished Training
# Best acc : 89
# Accuracy testing: 64 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0006905562676975517, reg : 3.942964552473012e-05, Finished Training
# Best acc : 89
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0011468365110742678, reg : 1.415556613950537e-05, Finished Training
# Best acc : 89
# Accuracy testing: 76 %
# Accuracy testing: 76 %
# Accuracy testing: 79 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0067421793114747905, reg : 4.076495603715542e-05, Finished Training
# Best acc : 89
# Accuracy testing: 73 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.004910174643189858, reg : 2.1567346055479237e-05, Finished Training
# Best acc : 89
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0011364758061944594, reg : 2.5761143101268556e-05, Finished Training
# Best acc : 89
# Accuracy testing: 80 %
# Accuracy testing: 83 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.001925819393610628, reg : 9.860711565303153e-05, Finished Training
# Best acc : 89
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.001330363169432504, reg : 2.1084953556976788e-05, Finished Training
# Best acc : 89
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.005446286628257649, reg : 8.946746901405679e-05, Finished Training
# Best acc : 89
# Accuracy testing: 68 %
# Accuracy testing: 64 %
# Accuracy testing: 63 %
# Accuracy testing: 62 %
# Accuracy testing: 62 %
# Accuracy testing: 63 %
# Accuracy testing: 64 %
# Accuracy testing: 66 %
# Accuracy testing: 67 %
# Accuracy testing: 69 %
# Accuracy testing: 73 %
# Accuracy testing: 75 %
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# lr : 0.00010222092488509152, reg : 5.413237817017057e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 77 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.003275554133412545, reg : 1.7824460065116274e-05, Finished Training
# Best acc : 89
# Accuracy testing: 64 %
# Accuracy testing: 61 %
# Accuracy testing: 66 %
# Accuracy testing: 73 %
# Accuracy testing: 76 %
# Accuracy testing: 83 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0002377999835247773, reg : 4.7509795959508416e-05, Finished Training
# Best acc : 89
# Accuracy testing: 63 %
# Accuracy testing: 68 %
# Accuracy testing: 75 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0003818278701826134, reg : 5.346313851445558e-05, Finished Training
# Best acc : 89
# Accuracy testing: 68 %
# Accuracy testing: 66 %
# Accuracy testing: 73 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# ...
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 86 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00951978493805087, reg : 7.881324588114242e-05, Finished Training
# Best acc : 89
# Accuracy testing: 58 %
# Accuracy testing: 60 %
# Accuracy testing: 61 %
# Accuracy testing: 63 %
# Accuracy testing: 65 %
# Accuracy testing: 68 %
# Accuracy testing: 71 %
# Accuracy testing: 76 %
# Accuracy testing: 77 %
# Accuracy testing: 78 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.0001380785793245353, reg : 8.403243969590726e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 77 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.003280176331703711, reg : 8.502793609634711e-05, Finished Training
# Best acc : 89
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0010921268802119427, reg : 2.255557028827263e-05, Finished Training
# Best acc : 89
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 81 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.005349517012885526, reg : 5.244494454318375e-05, Finished Training
# Best acc : 89
# Accuracy testing: 54 %
# Accuracy testing: 55 %
# Accuracy testing: 60 %
# Accuracy testing: 67 %
# Accuracy testing: 71 %
# Accuracy testing: 75 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00019293399864319999, reg : 8.344944885273149e-05, Finished Training
# Best acc : 89
# Accuracy testing: 72 %
# Accuracy testing: 77 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.003256833356413873, reg : 6.735197240574296e-05, Finished Training
# Best acc : 89
# Accuracy testing: 55 %
# Accuracy testing: 59 %
# Accuracy testing: 66 %
# Accuracy testing: 70 %
# Accuracy testing: 75 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00024125689866297248, reg : 2.2421060565915673e-05, Finished Training
# Best acc : 89
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.0015180120764183205, reg : 1.6333768179380638e-05, Finished Training
# Best acc : 89
# Accuracy testing: 61 %
# Accuracy testing: 74 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00046155338448371935, reg : 3.8990308774840926e-05, Finished Training
# Best acc : 89
# Accuracy testing: 75 %
# Accuracy testing: 76 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 80 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 88 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# Accuracy testing: 89 %
# lr : 0.006095825175264806, reg : 5.119444219256224e-05, Finished Training
# Best acc : 89
# Accuracy testing: 73 %
# Accuracy testing: 59 %
# Accuracy testing: 63 %
# Accuracy testing: 70 %
# Accuracy testing: 73 %
# Accuracy testing: 77 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 82 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 84 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00019888355408869248, reg : 9.797860766135853e-05, Finished Training
# Best acc : 89
# Accuracy testing: 67 %
# Accuracy testing: 66 %
# Accuracy testing: 72 %
# Accuracy testing: 77 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 83 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 85 %
# Accuracy testing: 86 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 87 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# Accuracy testing: 88 %
# lr : 0.00032914604299338066, reg : 8.55859939260572e-05, Finished Training
# Best acc : 89

# %%
class Net(nn.Module):
    def __init__(self, input_dim, classes):
        super().__init__()

        self.fc1 = nn.Linear(input_dim, 500)
        torch.nn.init.xavier_uniform_(self.fc1.weight)

        self.fc2 = nn.Linear(500, classes)
        torch.nn.init.xavier_uniform_(self.fc2.weight)
        # self.fc3 = nn.Linear(100, 30)
        # self.fc4 = nn.Linear(30, 30)
        # self.fc5 = nn.Linear(30, classes)
        # self.fc5 = nn.Linear(84, classes)

    def forward(self, x):
        x = x.float()
        # x = F.sigmoid(self.fc1(x))
        x = F.relu((self.fc1(x)))
        x = self.fc2(x)
        # x = F.relu(self.fc3(x))
        # x = F.relu(self.fc4(x))
        # x = self.fc5(x)

        # x = self.fc1(x)


        # x = F.relu(self.fc2(x))
        # x = self.fc(x)
        return x

# %%
criterion = nn.CrossEntropyLoss()
# criterion = nn.MultiMarginLoss()

# %%
loss_list = []
test_list = []
train_list = []
l1_ar = [2, 4, 8, 16, 32, 64, 128, 256, 512]

# for l1 in [512]:
for j in range(1):
  net = Net(351, 2)
  # lr = 0.00012760422205143742
  # lr = 0.00013022156954668927
  # lr =0.0002013597445353245
  # lr = 0.00014926566021498933
  # lr = 0.00013523158305498746
  lr = 0.0015666022369767846
  reg : 8.001732159058187e-05
  # print(f"=={l2}==")
  optimizer = optim.Adam(net.parameters(), lr=lr, weight_decay=1e-10) # 1.584618639910894e-05
  for epoch in range(50):  # loop over the dataset multiple times

      running_loss = 0.0
      for i, data in enumerate(loader_train, 0):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          labels = labels.long()
          # print(inputs.dtype)
          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = net(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          running_loss += loss.item()
          if i % 64 == 500:    # print every 2000 mini-batches
              print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
              running_loss = 0.0
      loss_list.append((running_loss / 2000))
      print(f"lr : {lr}", end=', ')
      print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')

      correct = 0
      total = 0
      with torch.no_grad():
          for data in loader_train:
              images, labels = data
              # calculate outputs by running images through the network
              outputs = net(images)
              # the class with the highest energy is what we choose as prediction
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              correct += (predicted == labels).sum().item()
      print(f'Accuracy training: {100 * correct // total} %')
      train_list.append((100 * correct // total))
      correct = 0
      total = 0
      # since we're not training, we don't need to calculate the gradients for our outputs
      with torch.no_grad():
          for data in loader_test:
              images, labels = data
              # calculate outputs by running images through the network
              outputs = net(images)
              # the class with the highest energy is what we choose as prediction
              _, predicted = torch.max(outputs.data, 1)
              total += labels.size(0)
              correct += (predicted == labels).sum().item()

      test_list.append((100 * correct // total))

      print(f'Accuracy testing: {100 * correct // total} %')

  # print('Finished Training')
# Out:
# lr : 0.0015666022369767846, [1,    67] loss: 0.021
# Accuracy training: 86 %
# Accuracy testing: 83 %
# lr : 0.0015666022369767846, [2,    67] loss: 0.014
# Accuracy training: 89 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [3,    67] loss: 0.010
# Accuracy training: 90 %
# Accuracy testing: 88 %
# lr : 0.0015666022369767846, [4,    67] loss: 0.008
# Accuracy training: 91 %
# Accuracy testing: 88 %
# lr : 0.0015666022369767846, [5,    67] loss: 0.007
# Accuracy training: 91 %
# Accuracy testing: 88 %
# lr : 0.0015666022369767846, [6,    67] loss: 0.007
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [7,    67] loss: 0.006
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [8,    67] loss: 0.006
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [9,    67] loss: 0.006
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [10,    67] loss: 0.006
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [11,    67] loss: 0.006
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [12,    67] loss: 0.006
# Accuracy training: 92 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [13,    67] loss: 0.005
# Accuracy training: 93 %
# Accuracy testing: 87 %
# lr : 0.0015666022369767846, [14,    67] loss: 0.005
# Accuracy training: 93 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [15,    67] loss: 0.005
# Accuracy training: 93 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [16,    67] loss: 0.005
# Accuracy training: 93 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [17,    67] loss: 0.005
# Accuracy training: 93 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [18,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [19,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [20,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [21,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [22,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [23,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [24,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 86 %
# lr : 0.0015666022369767846, [25,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [26,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [27,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [28,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [29,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [30,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [31,    67] loss: 0.005
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [32,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [33,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [34,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [35,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [36,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [37,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [38,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [39,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [40,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [41,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [42,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [43,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [44,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [45,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [46,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [47,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [48,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [49,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %
# lr : 0.0015666022369767846, [50,    67] loss: 0.004
# Accuracy training: 94 %
# Accuracy testing: 85 %

# %%
 max(test_list)
# Out:
# 88

# %%
sns.lineplot(x=[i for i in range(20)], y=loss_list).set(title='Loss 200 epoch')
# Out:
# [Text(0.5, 1.0, 'Loss 200 epoch')]

# %%
sns.lineplot(x=[i for i in range(20)], y=train_list)
sns.lineplot(x=[i for i in range(20)], y=test_list)
# Out:
# <Axes: >

# %%
sns.lineplot(x=[i for i in range(20)], y=loss_list).set(title='Loss 0.00012760422205143742')
# Out:
# [Text(0.5, 1.0, 'Loss 0.00012760422205143742')]

# %%
sns.lineplot(x=[i for i in range(20)], y=loss_list).set(title='Loss 0.00013022156954668927')
# Out:
# [Text(0.5, 1.0, 'Loss 0.00013022156954668927')]

# %%
sns.lineplot(x=[i for i in range(20)], y=loss_list).set(title='Loss 0.0002013597445353245')
# Out:
# [Text(0.5, 1.0, 'Loss 0.0002013597445353245')]

# %%
sns.lineplot(x=[i for i in range(20)], y=loss_list).set(title='Loss 0.00014926566021498933')
# Out:
# [Text(0.5, 1.0, 'Loss 0.00014926566021498933')]

# %%
sns.lineplot(x=[i for i in range(20)], y=loss_list).set(title='Loss 0.00013523158305498746')
# Out:
# [Text(0.5, 1.0, 'Loss 0.00013523158305498746')]

# %% [markdown]
# ## **SVM**

# %%
#Create a svm Classifier
clf = svm.SVC(kernel='linear') # Linear Kernel

#Train the model using the training sets
clf.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
clf
# Out:
# SVC(kernel='linear')

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7440476190476191

# %% [markdown]
# ## **SVM dengan pembeneran akurasi**

# %%
kernel = ['linear', 'poly', 'rbf', 'sigmoid']
best_acc = -1
degree = [i for i in range(1,20)]
scale = ['scale', 'auto']
for sc in [1]:

  for i in range(1):
    cache = 10**random.uniform(-5,5)
    print(f"cache : {cache}", end=', ')
    reg = 10**random.uniform(-1,1)
    # print(f"Kernel : {kern}, reg : {reg}", end=', ')
    #Create a svm Classifier
    clf = svm.SVC(kernel='sigmoid',
                  C=1.5106108189353196,
                  degree=1,
                  coef0=0.647517407284433,
                  tol=1.8359221883440502) # Linear Kernel

    #Train the model using the training sets
    clf.fit(X_train, y_train)

    #Predict the response for test dataset
    y_pred = clf.predict(X_test)
    train_acc = accuracy_score(y_train, clf.predict(X_train))
    acc = accuracy_score(y_test, y_pred)
    # print("Train Accuracy:", train_acc)
    print("Test Accuracy:", acc)
    # print()
    if acc>best_acc:
      best_acc = acc
print(f"Best acc : {best_acc}")
# Out:
# cache : 95923.2889354866, Test Accuracy: 0.8392857142857143
# Best acc : 0.8392857142857143

# %%
"""
sama tapi ganti preprocessing ke baru + k351
Best acc : 0.8452380952380952

tol : 1.8359221883440502, Test Accuracy: 0.7797619047619048
Best acc : 0.7797619047619048

coef : 0.647517407284433, Test Accuracy: 0.7678571428571429

Kernel : sigmoid
Train Accuracy: 0.8952095808383234
Test Accuracy: 0.7619047619047619

Kernel : sigmoid
Train Accuracy: 0.8712574850299402
Test Accuracy: 0.7559523809523809
"""
# Out:
#   File "<ipython-input-30-2315753863>", line 2
#     Train Accuracy: 0.8952095808383234
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## **Logistic regression**

# %%
# instantiate the model (using the default parameters)
logreg = LogisticRegression(random_state=16)

# fit the model with data
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)
train_acc = accuracy_score(y_train, logreg.predict(X_train))
acc = accuracy_score(y_test, y_pred)
print("Train Accuracy:", train_acc)
print("Test Accuracy:", acc)
# Out:
# Train Accuracy: 0.9251497005988024
# Test Accuracy: 0.7559523809523809

# %%
logreg
# Out:
# LogisticRegression(random_state=16)

# %%
# Create the confusion matrix
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot();

# %% [markdown]
# ## **Logistic regresion pembenaran akurasi**

# %%
pen = ['l2', 'elasticnet', None]
best_acc = -1

for sc in [1]:
  for penalty in range(1):
    c = 10**random.uniform(-5,5)
    # print(f"interc : {c}", end=', ')
    # print(f"Kernel : {kern}, reg : {reg}", end=', ')
    #Create a svm Classifier
  # instantiate the model (using the default parameters)
    logreg = LogisticRegression(random_state=16,
                                )

    # fit the model with data
    logreg.fit(X_train, y_train)

    #Predict the response for test dataset
    y_pred = logreg.predict(X_test)
    train_acc = accuracy_score(y_train, logreg.predict(X_train))
    acc = accuracy_score(y_test, y_pred)
    # print("Train Accuracy:", train_acc)
    print("Test Accuracy:", acc)
    # print()
    if acc>best_acc:
      best_acc = acc
print(f"Best acc : {best_acc}")
# Out:
# Test Accuracy: 0.8333333333333334
# Best acc : 0.8333333333333334

# %%
"""
ga ubah apa apa tapi feature scaling
Best acc : 0.8392857142857143


Best acc : 0.7559523809523809
"""
# Out:
# '\nga ubah apa apa tapi feature scaling\nBest acc : 0.8392857142857143\n\n\nBest acc : 0.7559523809523809\n'
